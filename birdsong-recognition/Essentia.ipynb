# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import _pickle as pickle
def save(file,name, folder = ""):
    if folder != "":
        outfile = open('./'+folder+'/'+name+'.pickle', 'wb')
    else:
        outfile = open(name+'.pickle', 'wb')
    pickle.dump(file, outfile)
    outfile.close
    
def load(name, folder = ""):
    if folder != "":
        outfile = open('./'+folder+'/'+name+'.pickle', 'rb')
    else:
        outfile = open(name+'.pickle', 'rb')
    file = pickle.load(outfile)
    outfile.close
    return file

# %%
import pyo
# Out:
# WxPython is not found for the current python version.
# Pyo will use a minimal GUI toolkit written with Tkinter (if available).
# This toolkit has limited functionnalities and is no more
# maintained or updated. If you want to use all of pyo's
# GUI features, you should install WxPython, available here:
# http://www.wxpython.org/

# %%
dir(pyo)
# Out:
# ['AToDB',
#  'AToDB_base',
#  'Abs',
#  'Adsr',
#  'Adsr_base',
#  'Allpass',
#  'Allpass2',
#  'Allpass2_base',
#  'AllpassWG',
#  'AllpassWG_base',
#  'Allpass_base',
#  'Atan2',
#  'AtanTable',
#  'AtanTable_base',
#  'Atone',
#  'Atone_base',
#  'AttackDetector',
#  'AttackDetector_base',
#  'Average',
#  'Average_base',
#  'Balance',
#  'Balance_base',
#  'BandSplit',
#  'BandSplit_base',
#  'BandSplitter_base',
#  'Beat',
#  'BeatAmpStream_base',
#  'BeatDurStream_base',
#  'BeatEndStream_base',
#  'BeatTapStream_base',
#  'Beat_base',
#  'Beater_base',
#  'Bendin',
#  'Bendin_base',
#  'Between',
#  'Between_base',
#  'Binaural',
#  'Binaural_base',
#  'Binauraler_base',
#  'Biquad',
#  'Biquad_base',
#  'Biquada',
#  'Biquada_base',
#  'Biquadx',
#  'Biquadx_base',
#  'Blit',
#  'Blit_base',
#  'BrownNoise',
#  'BrownNoise_base',
#  'ButBP',
#  'ButBP_base',
#  'ButBR',
#  'ButBR_base',
#  'ButHP',
#  'ButHP_base',
#  'ButLP',
#  'ButLP_base',
#  'CallAfter',
#  'CallAfter_base',
#  'CarToPol',
#  'CarToPol_base',
#  'Ceil',
#  'Centroid',
#  'Centroid_base',
#  'CentsToTranspo',
#  'CentsToTranspo_base',
#  'Change',
#  'Change_base',
#  'ChebyTable',
#  'ChebyTable_base',
#  'ChenLee',
#  'ChenLeeAlt_base',
#  'ChenLee_base',
#  'Choice',
#  'Choice_base',
#  'Chorus',
#  'Chorus_base',
#  'Clean_objects',
#  'Clip',
#  'Clip_base',
#  'Cloud',
#  'Cloud_base',
#  'Clouder_base',
#  'Compare',
#  'Compare_base',
#  'ComplexRes',
#  'ComplexRes_base',
#  'Compress',
#  'Compress_base',
#  'ControlRead',
#  'ControlRead_base',
#  'ControlRec',
#  'ControlRec_base',
#  'Convolve',
#  'Convolve_base',
#  'Cos',
#  'CosLogTable',
#  'CosLogTable_base',
#  'CosTable',
#  'CosTable_base',
#  'Count',
#  'Count_base',
#  'Counter',
#  'Counter_base',
#  'CrossFM',
#  'CrossFm_base',
#  'CtlScan',
#  'CtlScan2',
#  'CtlScan2_base',
#  'CtlScan_base',
#  'CurveTable',
#  'CurveTable_base',
#  'CvlVerb',
#  'CvlVerb_base',
#  'DBToA',
#  'DBToA_base',
#  'DCBlock',
#  'DCBlock_base',
#  'DOC_KEYWORDS',
#  'DataTable',
#  'DataTable_base',
#  'DefaultInstrument',
#  'Degrade',
#  'Degrade_base',
#  'Delay',
#  'Delay1',
#  'Delay1_base',
#  'Delay_base',
#  'Denorm',
#  'Denorm_base',
#  'Disto',
#  'Disto_base',
#  'Div',
#  'Dummy',
#  'Dummy_base',
#  'EQ',
#  'EQ_base',
#  'Euclide',
#  'EventCall',
#  'EventChoice',
#  'EventConditional',
#  'EventDrunk',
#  'EventDummy',
#  'EventFilter',
#  'EventGenerator',
#  'EventIndex',
#  'EventInstrument',
#  'EventKey',
#  'EventMarkov',
#  'EventNoise',
#  'EventScale',
#  'EventSeq',
#  'EventSlide',
#  'Events',
#  'Exp',
#  'ExpTable',
#  'ExpTable_base',
#  'Expand',
#  'Expand_base',
#  'Expr',
#  'Expr_base',
#  'Exprer_base',
#  'Expseg',
#  'Expseg_base',
#  'FFT',
#  'FFTMain_base',
#  'FFT_base',
#  'FILE_FORMATS',
#  'FM',
#  'FToM',
#  'FToM_base',
#  'FUNCTIONS_INIT_LINES',
#  'Fader',
#  'Fader_base',
#  'FastSine',
#  'FastSine_base',
#  'Floor',
#  'Fm_base',
#  'Follower',
#  'Follower2',
#  'Follower2_base',
#  'Follower_base',
#  'FourBand',
#  'FourBandMain_base',
#  'FourBand_base',
#  'FrameAccum',
#  'FrameAccumMain_base',
#  'FrameAccum_base',
#  'FrameDelta',
#  'FrameDeltaMain_base',
#  'FrameDelta_base',
#  'Freeverb',
#  'Freeverb_base',
#  'FreqShift',
#  'Gate',
#  'Gate_base',
#  'Granulator',
#  'Granulator_base',
#  'Granule',
#  'Granule_base',
#  'HRTF',
#  'HRTFData',
#  'HRTFData_base',
#  'HRTFSpatter_base',
#  'HRTF_base',
#  'HannTable',
#  'HannTable_base',
#  'HarmTable',
#  'HarmTable_base',
#  'Harmonizer',
#  'Harmonizer_base',
#  'Hilbert',
#  'HilbertMain_base',
#  'Hilbert_base',
#  'IFFT',
#  'IFFT_base',
#  'IRAverage',
#  'IRAverage_base',
#  'IRFM',
#  'IRFM_base',
#  'IRPulse',
#  'IRPulse_base',
#  'IRWinSinc',
#  'IRWinSinc_base',
#  'ImpulseResponseTables',
#  'Input',
#  'InputFader',
#  'InputFader_base',
#  'Input_base',
#  'Interp',
#  'Interp_base',
#  'Iter',
#  'Iter_base',
#  'LFO',
#  'LFO_base',
#  'LinTable',
#  'LinTable_base',
#  'Linseg',
#  'Linseg_base',
#  'Log',
#  'Log10',
#  'Log2',
#  'LogTable',
#  'LogTable_base',
#  'LogiMap',
#  'LogiMap_base',
#  'Lookup',
#  'Lookup_base',
#  'Looper',
#  'LooperTimeStream_base',
#  'Looper_base',
#  'Lorenz',
#  'LorenzAlt_base',
#  'Lorenz_base',
#  'MToF',
#  'MToF_base',
#  'MToT',
#  'MToT_base',
#  'M_Abs_base',
#  'M_Atan2_base',
#  'M_Ceil_base',
#  'M_Cos_base',
#  'M_Div_base',
#  'M_Exp_base',
#  'M_Floor_base',
#  'M_Log10_base',
#  'M_Log2_base',
#  'M_Log_base',
#  'M_Pow_base',
#  'M_Round_base',
#  'M_Sin_base',
#  'M_Sqrt_base',
#  'M_Sub_base',
#  'M_Tan_base',
#  'M_Tanh_base',
#  'MainParticle2_base',
#  'MainParticle_base',
#  'Map',
#  'MarkovGen',
#  'MatrixMorph',
#  'MatrixMorph_base',
#  'MatrixPointer',
#  'MatrixPointer_base',
#  'MatrixRec',
#  'MatrixRecLoop',
#  'MatrixRecLoop_base',
#  'MatrixRec_base',
#  'MatrixStream',
#  'Max',
#  'Max_base',
#  'Metro',
#  'Metro_base',
#  'MidiAdsr',
#  'MidiAdsr_base',
#  'MidiDelAdsr',
#  'MidiDelAdsr_base',
#  'MidiDispatcher',
#  'MidiDispatcher_base',
#  'MidiLinseg',
#  'MidiLinseg_base',
#  'MidiListener',
#  'MidiListener_base',
#  'MidiNote_base',
#  'Midictl',
#  'Midictl_base',
#  'Min',
#  'Min_base',
#  'Mirror',
#  'Mirror_base',
#  'Mix',
#  'Mix_base',
#  'Mixer',
#  'MixerVoice_base',
#  'Mixer_base',
#  'MoogLP',
#  'MoogLP_base',
#  'MultiBand',
#  'MultiBandMain_base',
#  'MultiBand_base',
#  'NO_WX_MESSAGE',
#  'NewMatrix',
#  'NewMatrix_base',
#  'NewTable',
#  'NewTable_base',
#  'NextTrig',
#  'NextTrig_base',
#  'Noise',
#  'Noise_base',
#  'Notein',
#  'NoteinRead',
#  'NoteinRead_base',
#  'NoteinRec',
#  'NoteinRec_base',
#  'NoteinTrig_base',
#  'Notein_base',
#  'OBJECTS_TREE',
#  'Osc',
#  'OscBank',
#  'OscBank_base',
#  'OscDataReceive',
#  'OscDataReceive_base',
#  'OscDataSend',
#  'OscDataSend_base',
#  'OscListReceive',
#  'OscListReceive_base',
#  'OscListReceiver_base',
#  'OscListener',
#  'OscListenerLock',
#  'OscListener_base',
#  'OscLoop',
#  'OscLoop_base',
#  'OscReceive',
#  'OscReceive_base',
#  'OscReceiver_base',
#  'OscSend',
#  'OscSend_base',
#  'OscTrig',
#  'OscTrig_base',
#  'Osc_base',
#  'PVAddSynth',
#  'PVAddSynth_base',
#  'PVAmpMod',
#  'PVAmpMod_base',
#  'PVAnal',
#  'PVAnal_base',
#  'PVBufLoops',
#  'PVBufLoops_base',
#  'PVBufTabLoops',
#  'PVBufTabLoops_base',
#  'PVBuffer',
#  'PVBuffer_base',
#  'PVCross',
#  'PVCross_base',
#  'PVDelay',
#  'PVDelay_base',
#  'PVFilter',
#  'PVFilter_base',
#  'PVFreqMod',
#  'PVFreqMod_base',
#  'PVGate',
#  'PVGate_base',
#  'PVMix',
#  'PVMix_base',
#  'PVMorph',
#  'PVMorph_base',
#  'PVMult',
#  'PVMult_base',
#  'PVShift',
#  'PVShift_base',
#  'PVStream',
#  'PVSynth',
#  'PVSynth_base',
#  'PVTranspose',
#  'PVTranspose_base',
#  'PVVerb',
#  'PVVerb_base',
#  'PYO_EVENT_FILTER_ABS',
#  'PYO_EVENT_FILTER_CEIL',
#  'PYO_EVENT_FILTER_CLIP',
#  'PYO_EVENT_FILTER_DEVIATE',
#  'PYO_EVENT_FILTER_FLOOR',
#  'PYO_EVENT_FILTER_IFTRUE',
#  'PYO_EVENT_FILTER_RESCALE',
#  'PYO_EVENT_FILTER_ROUND',
#  'PYO_EVENT_FILTER_SCALE',
#  'PYO_EVENT_FILTER_SNAP',
#  'PYO_EVENT_OPERATOR_ADD',
#  'PYO_EVENT_OPERATOR_DIV',
#  'PYO_EVENT_OPERATOR_FLR',
#  'PYO_EVENT_OPERATOR_MOD',
#  'PYO_EVENT_OPERATOR_MUL',
#  'PYO_EVENT_OPERATOR_POW',
#  'PYO_EVENT_OPERATOR_SUB',
#  'PYO_USE_WX',
#  'PYO_VERSION',
#  'PadSynthTable',
#  'PadSynthTable_base',
#  'Pan',
#  'Pan_base',
#  'Panner_base',
#  'ParaTable',
#  'ParaTable_base',
#  'PartialTable',
#  'Particle',
#  'Particle2',
#  'Particle2_base',
#  'Particle_base',
#  'Pattern',
#  'Pattern_base',
#  'PeakAmp',
#  'PeakAmp_base',
#  'Percent',
#  'Percent_base',
#  'Phaser',
#  'Phaser_base',
#  'Phasor',
#  'Phasor_base',
#  'PinkNoise',
#  'PinkNoise_base',
#  'Pointer',
#  'Pointer2',
#  'Pointer2_base',
#  'Pointer_base',
#  'PolToCar',
#  'PolToCar_base',
#  'Port',
#  'Port_base',
#  'Pow',
#  'Print',
#  'Print_base',
#  'Programin',
#  'Programin_base',
#  'Pulsar',
#  'Pulsar_base',
#  'PyoArgumentTypeError',
#  'PyoError',
#  'PyoGuiControlSlider',
#  'PyoGuiGrapher',
#  'PyoGuiKeyboard',
#  'PyoGuiMultiSlider',
#  'PyoGuiScope',
#  'PyoGuiSndView',
#  'PyoGuiSpectrum',
#  'PyoGuiVuMeter',
#  'PyoMatrixObject',
#  'PyoObject',
#  'PyoObjectBase',
#  'PyoPVObject',
#  'PyoServerStateException',
#  'PyoTableObject',
#  'RCOsc',
#  'RCOsc_base',
#  'RMS',
#  'RMS_base',
#  'RandDur',
#  'RandDur_base',
#  'RandInt',
#  'RandInt_base',
#  'Randh',
#  'Randh_base',
#  'Randi',
#  'Randi_base',
#  'RawMidi',
#  'RawMidi_base',
#  'Record',
#  'Record_base',
#  'Resample',
#  'Resample_base',
#  'Reson',
#  'Reson_base',
#  'Resonx',
#  'Resonx_base',
#  'Rossler',
#  'RosslerAlt_base',
#  'Rossler_base',
#  'Round',
#  'SDelay',
#  'SDelay_base',
#  'SLMap',
#  'SLMapDur',
#  'SLMapFreq',
#  'SLMapMul',
#  'SLMapPan',
#  'SLMapPhase',
#  'SLMapQ',
#  'SNDS_PATH',
#  'SPan',
#  'SPan_base',
#  'SPanner_base',
#  'STRev',
#  'STRev_base',
#  'STReverb_base',
#  'SVF',
#  'SVF2',
#  'SVF2_base',
#  'SVF_base',
#  'SampHold',
#  'SampHold_base',
#  'SawTable',
#  'Scale',
#  'Scale_base',
#  'Scope',
#  'Scope_base',
#  'Score',
#  'Score_base',
#  'Select',
#  'Select_base',
#  'Selector',
#  'Selector_base',
#  'Seq',
#  'Seq_base',
#  'Seqer_base',
#  'Server',
#  'Server_base',
#  'SfMarkerLoop_base',
#  'SfMarkerLooper',
#  'SfMarkerLooper_base',
#  'SfMarkerShuffle_base',
#  'SfMarkerShuffler',
#  'SfMarkerShuffler_base',
#  'SfPlay_base',
#  'SfPlayer',
#  'SfPlayer_base',
#  'SharedTable',
#  'SharedTable_base',
#  'Sig',
#  'SigTo',
#  'SigTo_base',
#  'Sig_base',
#  'Sin',
#  'SincTable',
#  'SincTable_base',
#  'Sine',
#  'SineLoop',
#  'SineLoop_base',
#  'Sine_base',
#  'SmoothDelay',
#  'SmoothDelay_base',
#  'Snap',
#  'Snap_base',
#  'SndTable',
#  'SndTable_base',
#  'Spectrum',
#  'Spectrum_base',
#  'Sqrt',
#  'SquareTable',
#  'Stream',
#  'Sub',
#  'SumOsc',
#  'SumOsc_base',
#  'SuperSaw',
#  'SuperSaw_base',
#  'Switch',
#  'Switch_base',
#  'Switcher_base',
#  'TableFill',
#  'TableFill_base',
#  'TableIndex',
#  'TableIndex_base',
#  'TableMorph',
#  'TableMorph_base',
#  'TablePut',
#  'TablePut_base',
#  'TableRead',
#  'TableRead_base',
#  'TableRec',
#  'TableRecTimeStream_base',
#  'TableRec_base',
#  'TableScale',
#  'TableScale_base',
#  'TableScan',
#  'TableScan_base',
#  'TableStream',
#  'TableWrite',
#  'TableWrite_base',
#  'Tan',
#  'Tanh',
#  'Thresh',
#  'Thresh_base',
#  'Timer',
#  'Timer_base',
#  'Tone',
#  'Tone_base',
#  'Touchin',
#  'Touchin_base',
#  'TrackHold',
#  'TrackHold_base',
#  'TranspoToCents',
#  'TranspoToCents_base',
#  'Trig',
#  'TrigBurst',
#  'TrigBurstAmpStream_base',
#  'TrigBurstDurStream_base',
#  'TrigBurstEndStream_base',
#  'TrigBurstTapStream_base',
#  'TrigBurst_base',
#  'TrigBurster_base',
#  'TrigChoice',
#  'TrigChoice_base',
#  'TrigEnv',
#  'TrigEnv_base',
#  'TrigExpseg',
#  'TrigExpseg_base',
#  'TrigFunc',
#  'TrigFunc_base',
#  'TrigLinseg',
#  'TrigLinseg_base',
#  'TrigRand',
#  'TrigRandInt',
#  'TrigRandInt_base',
#  'TrigRand_base',
#  'TrigTableRec',
#  'TrigTableRecTimeStream_base',
#  'TrigTableRec_base',
#  'TrigVal',
#  'TrigVal_base',
#  'TrigXnoise',
#  'TrigXnoiseMidi',
#  'TrigXnoiseMidi_base',
#  'TrigXnoise_base',
#  'Trig_base',
#  'TriggerDummy_base',
#  'TriggerStream',
#  'USE_DOUBLE',
#  'Urn',
#  'Urn_base',
#  'VarPort',
#  'VarPort_base',
#  'Vectral',
#  'VectralMain_base',
#  'Vectral_base',
#  'Vocoder',
#  'Vocoder_base',
#  'VoiceManager',
#  'VoiceManager_base',
#  'WGVerb',
#  'WGVerb_base',
#  'WITH_EXTERNALS',
#  'Waveguide',
#  'Waveguide_base',
#  'WeakMethod',
#  'WinTable',
#  'WinTable_base',
#  'Wrap',
#  'Wrap_base',
#  'XNOISE_DICT',
#  'Xnoise',
#  'XnoiseDur',
#  'XnoiseDur_base',
#  'XnoiseMidi',
#  'XnoiseMidi_base',
#  'Xnoise_base',
#  'Yin',
#  'Yin_base',
#  'ZCross',
#  'ZCross_base',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_pyo',
#  'absolute_import',
#  'aifc',
#  'analysis',
#  'arithmetic',
#  'assertOSCSupport',
#  'beatToDur',
#  'builtins',
#  'bytes_t',
#  'call',
#  'class_args',
#  'controls',
#  'convertArgsToLists',
#  'convertStringToSysEncoding',
#  'copy',
#  'createCtrlWindow',
#  'createDataGraphWindow',
#  'createExprEditorWindow',
#  'createGraphWindow',
#  'createNoteinKeyboardWindow',
#  'createScopeWindow',
#  'createServerGUI',
#  'createSndViewTableWindow',
#  'createSpectrumWindow',
#  'createViewMatrixWindow',
#  'createViewTableWindow',
#  'current_pyo',
#  'current_pyo_path',
#  'degreeToMidiNote',
#  'distanceToSegment',
#  'division',
#  'downsamp',
#  'dynamics',
#  'effects',
#  'events',
#  'example',
#  'expression',
#  'filters',
#  'floatmap',
#  'fourier',
#  'generators',
#  'getPrecision',
#  'getPyoExamples',
#  'getPyoKeywords',
#  'getValueFromAttribute',
#  'getVersion',
#  'getWeakMethodRef',
#  'get_random_integer',
#  'hrtf',
#  'hzToMidi',
#  'inf',
#  'inspect',
#  'isAudioObject',
#  'isMatrixObject',
#  'isPVObject',
#  'isTableObject',
#  'lib',
#  'linToCosCurve',
#  'listscramble',
#  'locale',
#  'log10',
#  'math',
#  'matrixprocess',
#  'midi',
#  'midiNoteToDegree',
#  'midiToHz',
#  'midiToTranspo',
#  'opensndctrl',
#  'os',
#  'p_downsamp',
#  'p_savefile',
#  'p_savefileFromTable',
#  'p_sndinfo',
#  'p_upsamp',
#  'pa_count_devices',
#  'pa_count_host_apis',
#  'pa_get_default_devices_from_host',
#  'pa_get_default_host_api',
#  'pa_get_default_input',
#  'pa_get_default_output',
#  'pa_get_devices_infos',
#  'pa_get_input_devices',
#  'pa_get_input_max_channels',
#  'pa_get_output_devices',
#  'pa_get_output_max_channels',
#  'pa_get_version',
#  'pa_get_version_text',
#  'pa_list_devices',
#  'pa_list_host_apis',
#  'pan',
#  'pattern',
#  'phasevoc',
#  'pi',
#  'players',
#  'pm_count_devices',
#  'pm_get_default_input',
#  'pm_get_default_output',
#  'pm_get_input_devices',
#  'pm_get_output_devices',
#  'pm_list_devices',
#  'pow',
#  'print_function',
#  'proxy',
#  'pyoArgsAssert',
#  'random',
#  'randoms',
#  'reducePoints',
#  'removeExtraDecimals',
#  'rescale',
#  'sampsToSec',
#  'savefile',
#  'savefileFromTable',
#  'secToSamps',
#  'serverBooted',
#  'serverCreated',
#  'sndinfo',
#  'stringencode',
#  'sys',
#  'tableprocess',
#  'tempfile',
#  'threading',
#  'time',
#  'to_unicode',
#  'tobytes',
#  'triggers',
#  'unicode_t',
#  'upsamp',
#  'utils',
#  'weakref',
#  'withCoreaudio',
#  'withJack',
#  'withOSC',
#  'withPortaudio',
#  'withPortmidi',
#  'wrap',
#  'wxgui']
