# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm.auto import tqdm
import os
import random
from copy import deepcopy
import _pickle as pickle
import gc
from multiprocess import Pool
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score
from tensorflow.keras.preprocessing.text import Tokenizer
from sklearn.preprocessing import KBinsDiscretizer

from tensorflow.keras.optimizers import Adam, SGD
def save(file,name, folder = ""):
    if folder != "":
        outfile = open('./'+folder+'/'+name+'.pickle', 'wb')
    else:
        outfile = open(name+'.pickle', 'wb')
    pickle.dump(file, outfile, protocol=4)
    outfile.close
    
def load(name, folder = ""):
    
    if folder != "":
        outfile = open('./'+folder+'/'+name+'.pickle', 'rb')
    else:
        outfile = open(name+'.pickle', 'rb')
    file = pickle.load(outfile)
    outfile.close
    return file

class Discretiser:
    def __init__(self, nbins):
        self.nbins = nbins-1
        self.map_to = np.arange(self.nbins)/self.nbins
        
    def fit(self, X):
        ## X is a one dimension np array
        self.map_from = np.quantile(X, self.map_to)
        
    def transform(self, X):
        X1 = (np.interp(X, self.map_from, self.map_to, left=0, right=1, period=None) * self.nbins).astype(int)
        return X1
    
from tf_transformers2 import *
from tensorflow.keras.layers import Input, Dense, Dropout, TimeDistributed, LSTM
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

# %%
## features present
exercise to predict    ## cat
part of exercise       ## cat
gtag of exercise       ## cat
cluster of exercise    ## cat
qmean on user          ## num
qmean on content
container              ## num
timestamp              ## num

## content / user

## feature past
avg correctness
number explanation
number question
number lecture
avg elapsed time

## per part
avg correct
number explained
number lecture
number question
avg elapsed time
time since first question
time since last question
time since last lecture

## Per cluster
avg correct
number explained
number lecture
number question
avg elapsed time
time since first question
time since last question
time since last lecture

# %%
## Segments          28
user                 1
content              1
parts                6
cluster              20

## Time windows      17 possibles
history
# based on id
first five / ten /twenty / 100
last five / ten / twenty / 100
# Based on time
last 1/5/12/24/168/720 hours
first 1/5/12/24/168/720 hours

## Kpis              4 possibles 
interaction_type
time spent
time elapsed
explanation

## Kpis type         7 possibles
count
mean
hmean
std
min
max
slope - % improvement



#####################################
## Total 13328 features

# %%
def get_user_features(user_dic):
    import numpy as np
    import matplotlib.pyplot as plt
    import pandas as pd
    from tqdm.auto import tqdm
    from features_util import prepare, get_current_past, get_features
    import random
    user = prepare(user_dic)
    
    ##sampling
    seq_len = len(user['exercise_id'])
    r = random.randint(min(3, seq_len), min(10, seq_len))
    ids_to_fetch = np.random.choice(list(range(seq_len)), size = r, replace = False) 
               
    mat = np.zeros((r, 1049))
    for j, i in enumerate(tqdm(ids_to_fetch)):
        current, past = get_current_past(user, i)
        final = get_features(current, past)
        k = list(final.keys())
        v = list(final.values())
        mat[j] = v
    df = pd.DataFrame(mat, columns= k)
    return df

# %%
from multiprocess import Pool
import pandas as pd
from tqdm.notebook import tqdm
from features_util import load, save
import os

p = Pool(10)
for elt in tqdm(os.listdir('user_batch_2000')):
    if not(elt in os.listdir('user_batch_lgb_2000')):
        dico = load(elt.split('.')[0], 'user_batch_2000')
        list_dico = [dico[elt] for elt in dico]
        df = p.map(get_user_features, list_dico)
        df = pd.concat(df)
        save(df, elt.split('.')[0], 'user_batch_lgb_2000')
p.close()

# %%
df_train = []
for i in tqdm(range(1,30)):
    df_train.append(load('batch_'+str(i), 'user_batch_lgb_2000'))
df_train = pd.concat(df_train)  
df_test = []
for i in tqdm(range(40,50)):
    df_test.append(load('batch_'+str(i), 'user_batch_lgb_2000'))
df_test = pd.concat(df_test)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=29.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=10.0), HTML(value='')))

# %%
df_train = df_train[df_train['correctness']!=-1]
df_test = df_test[df_test['correctness']!=-1]
X_train, y_train = df_train[[elt for elt in df_train.columns if not(elt == 'correctness')]], df_train['correctness'].values
X_test, y_test = df_test[[elt for elt in df_test.columns if not(elt == 'correctness')]], df_test['correctness'].values

del df_train
del df_test
gc.collect()
# Out:
# 38

# %%
import lightgbm as lgb
clf = lgb.LGBMClassifier(max_depth = -1, n_estimators = 10000, n_jobs = 12, silent = False)
clf.fit(X_train, y_train, eval_set =(X_test, y_test), eval_metric = 'auc')
# Out:
# [LightGBM] [Info] Number of positive: 201628, number of negative: 167369
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 2.884346 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 207203
# [LightGBM] [Info] Number of data points in the train set: 368997, number of used features: 995
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.546422 -> initscore=0.186223
# [LightGBM] [Info] Start training from score 0.186223
# [1]	valid_0's auc: 0.739731	valid_0's binary_logloss: 0.67236
# [2]	valid_0's auc: 0.744644	valid_0's binary_logloss: 0.658666
# [3]	valid_0's auc: 0.745662	valid_0's binary_logloss: 0.647414
# [4]	valid_0's auc: 0.74731	valid_0's binary_logloss: 0.637959
# [5]	valid_0's auc: 0.747904	valid_0's binary_logloss: 0.63007
# [6]	valid_0's auc: 0.748403	valid_0's binary_logloss: 0.623437
# [7]	valid_0's auc: 0.748834	valid_0's binary_logloss: 0.617879
# [8]	valid_0's auc: 0.749293	valid_0's binary_logloss: 0.613158
# [9]	valid_0's auc: 0.749573	valid_0's binary_logloss: 0.609208
# [10]	valid_0's auc: 0.75001	valid_0's binary_logloss: 0.605783
# [11]	valid_0's auc: 0.750426	valid_0's binary_logloss: 0.602892
# [12]	valid_0's auc: 0.750709	valid_0's binary_logloss: 0.600425
# [13]	valid_0's auc: 0.751029	valid_0's binary_logloss: 0.598294
# [14]	valid_0's auc: 0.751318	valid_0's binary_logloss: 0.59647
# [15]	valid_0's auc: 0.75164	valid_0's binary_logloss: 0.594874
# [16]	valid_0's auc: 0.751923	valid_0's binary_logloss: 0.593507
# [17]	valid_0's auc: 0.752233	valid_0's binary_logloss: 0.592276
# [18]	valid_0's auc: 0.752463	valid_0's binary_logloss: 0.591245
# [19]	valid_0's auc: 0.752717	valid_0's binary_logloss: 0.590302
# [20]	valid_0's auc: 0.752977	valid_0's binary_logloss: 0.589457
# [21]	valid_0's auc: 0.753229	valid_0's binary_logloss: 0.588724
# [22]	valid_0's auc: 0.753498	valid_0's binary_logloss: 0.58806
# [23]	valid_0's auc: 0.753728	valid_0's binary_logloss: 0.587473
# [24]	valid_0's auc: 0.753932	valid_0's binary_logloss: 0.586983
# [25]	valid_0's auc: 0.754112	valid_0's binary_logloss: 0.586514
# [26]	valid_0's auc: 0.754307	valid_0's binary_logloss: 0.586109
# [27]	valid_0's auc: 0.754487	valid_0's binary_logloss: 0.585734
# [28]	valid_0's auc: 0.754607	valid_0's binary_logloss: 0.585427
# [29]	valid_0's auc: 0.75479	valid_0's binary_logloss: 0.585098
# [30]	valid_0's auc: 0.754976	valid_0's binary_logloss: 0.584778
# [31]	valid_0's auc: 0.755149	valid_0's binary_logloss: 0.584495
# [32]	valid_0's auc: 0.755293	valid_0's binary_logloss: 0.584256
# [33]	valid_0's auc: 0.755442	valid_0's binary_logloss: 0.584041
# [34]	valid_0's auc: 0.755551	valid_0's binary_logloss: 0.583842
# [35]	valid_0's auc: 0.755722	valid_0's binary_logloss: 0.583613
# [36]	valid_0's auc: 0.755892	valid_0's binary_logloss: 0.583408
# [37]	valid_0's auc: 0.756009	valid_0's binary_logloss: 0.583239
# [38]	valid_0's auc: 0.756175	valid_0's binary_logloss: 0.583032
# [39]	valid_0's auc: 0.756301	valid_0's binary_logloss: 0.582865
# [40]	valid_0's auc: 0.756424	valid_0's binary_logloss: 0.58271
# [41]	valid_0's auc: 0.756527	valid_0's binary_logloss: 0.582585
# [42]	valid_0's auc: 0.756613	valid_0's binary_logloss: 0.582466
# [43]	valid_0's auc: 0.756727	valid_0's binary_logloss: 0.582322
# [44]	valid_0's auc: 0.756798	valid_0's binary_logloss: 0.582234
# [45]	valid_0's auc: 0.756898	valid_0's binary_logloss: 0.582103
# [46]	valid_0's auc: 0.756968	valid_0's binary_logloss: 0.582011
# [47]	valid_0's auc: 0.757058	valid_0's binary_logloss: 0.581898
# [48]	valid_0's auc: 0.757125	valid_0's binary_logloss: 0.581806
# [49]	valid_0's auc: 0.757184	valid_0's binary_logloss: 0.581731
# [50]	valid_0's auc: 0.757233	valid_0's binary_logloss: 0.581669
# [51]	valid_0's auc: 0.757248	valid_0's binary_logloss: 0.581636
# [52]	valid_0's auc: 0.757322	valid_0's binary_logloss: 0.581545
# [53]	valid_0's auc: 0.75736	valid_0's binary_logloss: 0.58149
# [54]	valid_0's auc: 0.757415	valid_0's binary_logloss: 0.581419
# [55]	valid_0's auc: 0.757423	valid_0's binary_logloss: 0.581399
# [56]	valid_0's auc: 0.757479	valid_0's binary_logloss: 0.581325
# [57]	valid_0's auc: 0.757519	valid_0's binary_logloss: 0.581279
# [58]	valid_0's auc: 0.75755	valid_0's binary_logloss: 0.581235
# [59]	valid_0's auc: 0.757572	valid_0's binary_logloss: 0.581212
# [60]	valid_0's auc: 0.757581	valid_0's binary_logloss: 0.581203
# [61]	valid_0's auc: 0.757628	valid_0's binary_logloss: 0.581148
# [62]	valid_0's auc: 0.757658	valid_0's binary_logloss: 0.581109
# [63]	valid_0's auc: 0.757701	valid_0's binary_logloss: 0.581062
# [64]	valid_0's auc: 0.757738	valid_0's binary_logloss: 0.58102
# [65]	valid_0's auc: 0.757736	valid_0's binary_logloss: 0.581021
# [66]	valid_0's auc: 0.757739	valid_0's binary_logloss: 0.581013
# [67]	valid_0's auc: 0.757801	valid_0's binary_logloss: 0.580948
# [68]	valid_0's auc: 0.757803	valid_0's binary_logloss: 0.58094
# [69]	valid_0's auc: 0.75782	valid_0's binary_logloss: 0.580922
# [70]	valid_0's auc: 0.757847	valid_0's binary_logloss: 0.580901
# [71]	valid_0's auc: 0.757842	valid_0's binary_logloss: 0.580894
# [72]	valid_0's auc: 0.757858	valid_0's binary_logloss: 0.580879
# [73]	valid_0's auc: 0.757865	valid_0's binary_logloss: 0.58087
# [74]	valid_0's auc: 0.757884	valid_0's binary_logloss: 0.580852
# [75]	valid_0's auc: 0.757896	valid_0's binary_logloss: 0.580845
# [76]	valid_0's auc: 0.757911	valid_0's binary_logloss: 0.580836
# [77]	valid_0's auc: 0.757937	valid_0's binary_logloss: 0.580803
# [78]	valid_0's auc: 0.757988	valid_0's binary_logloss: 0.580754
# [79]	valid_0's auc: 0.758031	valid_0's binary_logloss: 0.580699
# [80]	valid_0's auc: 0.758036	valid_0's binary_logloss: 0.580692
# [81]	valid_0's auc: 0.758021	valid_0's binary_logloss: 0.580702
# [82]	valid_0's auc: 0.758031	valid_0's binary_logloss: 0.580687
# [83]	valid_0's auc: 0.758016	valid_0's binary_logloss: 0.5807
# [84]	valid_0's auc: 0.758024	valid_0's binary_logloss: 0.580686
# [85]	valid_0's auc: 0.758032	valid_0's binary_logloss: 0.580683
# [86]	valid_0's auc: 0.75802	valid_0's binary_logloss: 0.580693
# [87]	valid_0's auc: 0.758035	valid_0's binary_logloss: 0.580683
# [88]	valid_0's auc: 0.758019	valid_0's binary_logloss: 0.5807
# [89]	valid_0's auc: 0.758025	valid_0's binary_logloss: 0.580691
# [90]	valid_0's auc: 0.758032	valid_0's binary_logloss: 0.580679
# [91]	valid_0's auc: 0.758033	valid_0's binary_logloss: 0.580677
# [92]	valid_0's auc: 0.758042	valid_0's binary_logloss: 0.580672
# [93]	valid_0's auc: 0.758054	valid_0's binary_logloss: 0.580658
# [94]	valid_0's auc: 0.758057	valid_0's binary_logloss: 0.580654
# [95]	valid_0's auc: 0.758103	valid_0's binary_logloss: 0.580603
# [96]	valid_0's auc: 0.758096	valid_0's binary_logloss: 0.58061
# [97]	valid_0's auc: 0.758113	valid_0's binary_logloss: 0.580593
# [98]	valid_0's auc: 0.758108	valid_0's binary_logloss: 0.580596
# [99]	valid_0's auc: 0.758117	valid_0's binary_logloss: 0.580589
# [100]	valid_0's auc: 0.758125	valid_0's binary_logloss: 0.580578
# [101]	valid_0's auc: 0.758115	valid_0's binary_logloss: 0.580589
# [102]	valid_0's auc: 0.75811	valid_0's binary_logloss: 0.580595
# [103]	valid_0's auc: 0.758113	valid_0's binary_logloss: 0.580594
# [104]	valid_0's auc: 0.758126	valid_0's binary_logloss: 0.580573
# [105]	valid_0's auc: 0.758111	valid_0's binary_logloss: 0.580585
# [106]	valid_0's auc: 0.758101	valid_0's binary_logloss: 0.580594
# [107]	valid_0's auc: 0.758103	valid_0's binary_logloss: 0.580591
# [108]	valid_0's auc: 0.758094	valid_0's binary_logloss: 0.5806
# [109]	valid_0's auc: 0.758163	valid_0's binary_logloss: 0.58054
# [110]	valid_0's auc: 0.758155	valid_0's binary_logloss: 0.580543
# [111]	valid_0's auc: 0.758148	valid_0's binary_logloss: 0.580543
# [112]	valid_0's auc: 0.758152	valid_0's binary_logloss: 0.580538
# [113]	valid_0's auc: 0.758137	valid_0's binary_logloss: 0.580549
# [114]	valid_0's auc: 0.758191	valid_0's binary_logloss: 0.580497
# [115]	valid_0's auc: 0.758192	valid_0's binary_logloss: 0.580497
# [116]	valid_0's auc: 0.758187	valid_0's binary_logloss: 0.580501
# [117]	valid_0's auc: 0.75819	valid_0's binary_logloss: 0.580497
# [118]	valid_0's auc: 0.758185	valid_0's binary_logloss: 0.580499
# [119]	valid_0's auc: 0.75819	valid_0's binary_logloss: 0.580497
# [120]	valid_0's auc: 0.758205	valid_0's binary_logloss: 0.580472
# [121]	valid_0's auc: 0.758193	valid_0's binary_logloss: 0.580483
# [122]	valid_0's auc: 0.758195	valid_0's binary_logloss: 0.580478
# [123]	valid_0's auc: 0.758177	valid_0's binary_logloss: 0.580493
# [124]	valid_0's auc: 0.758178	valid_0's binary_logloss: 0.580491
# [125]	valid_0's auc: 0.758192	valid_0's binary_logloss: 0.580476
# [126]	valid_0's auc: 0.758196	valid_0's binary_logloss: 0.580473
# [127]	valid_0's auc: 0.758208	valid_0's binary_logloss: 0.580464
# [128]	valid_0's auc: 0.758204	valid_0's binary_logloss: 0.580465
# [129]	valid_0's auc: 0.758209	valid_0's binary_logloss: 0.580459
# [130]	valid_0's auc: 0.758257	valid_0's binary_logloss: 0.580408
# [131]	valid_0's auc: 0.758251	valid_0's binary_logloss: 0.580413
# [132]	valid_0's auc: 0.758276	valid_0's binary_logloss: 0.580383
# [133]	valid_0's auc: 0.758281	valid_0's binary_logloss: 0.580376
# [134]	valid_0's auc: 0.758286	valid_0's binary_logloss: 0.580371
# [135]	valid_0's auc: 0.758274	valid_0's binary_logloss: 0.580383
# [136]	valid_0's auc: 0.758252	valid_0's binary_logloss: 0.5804
# [137]	valid_0's auc: 0.758231	valid_0's binary_logloss: 0.580417
# [138]	valid_0's auc: 0.758224	valid_0's binary_logloss: 0.580422
# [139]	valid_0's auc: 0.75822	valid_0's binary_logloss: 0.580422
# [140]	valid_0's auc: 0.75822	valid_0's binary_logloss: 0.580424
# [141]	valid_0's auc: 0.758244	valid_0's binary_logloss: 0.580407
# [142]	valid_0's auc: 0.75824	valid_0's binary_logloss: 0.580411
# [143]	valid_0's auc: 0.758228	valid_0's binary_logloss: 0.580427
# [144]	valid_0's auc: 0.758212	valid_0's binary_logloss: 0.580441
# [145]	valid_0's auc: 0.758199	valid_0's binary_logloss: 0.58045
# [146]	valid_0's auc: 0.758197	valid_0's binary_logloss: 0.58045
# [147]	valid_0's auc: 0.758216	valid_0's binary_logloss: 0.580427
# [148]	valid_0's auc: 0.758207	valid_0's binary_logloss: 0.580435
# [149]	valid_0's auc: 0.758222	valid_0's binary_logloss: 0.580424
# [150]	valid_0's auc: 0.758223	valid_0's binary_logloss: 0.580423
# [151]	valid_0's auc: 0.758206	valid_0's binary_logloss: 0.580435
# [152]	valid_0's auc: 0.758214	valid_0's binary_logloss: 0.580428
# [153]	valid_0's auc: 0.758214	valid_0's binary_logloss: 0.580431
# [154]	valid_0's auc: 0.758224	valid_0's binary_logloss: 0.580423
# [155]	valid_0's auc: 0.758261	valid_0's binary_logloss: 0.580391
# [156]	valid_0's auc: 0.75825	valid_0's binary_logloss: 0.580399
# [157]	valid_0's auc: 0.758258	valid_0's binary_logloss: 0.580389
# [158]	valid_0's auc: 0.758252	valid_0's binary_logloss: 0.580397
# [159]	valid_0's auc: 0.758258	valid_0's binary_logloss: 0.580391
# [160]	valid_0's auc: 0.758264	valid_0's binary_logloss: 0.580388
# [161]	valid_0's auc: 0.758247	valid_0's binary_logloss: 0.580404
# [162]	valid_0's auc: 0.758256	valid_0's binary_logloss: 0.580393
# [163]	valid_0's auc: 0.758246	valid_0's binary_logloss: 0.580403
# [164]	valid_0's auc: 0.758272	valid_0's binary_logloss: 0.580377
# [165]	valid_0's auc: 0.758274	valid_0's binary_logloss: 0.580376
# [166]	valid_0's auc: 0.758277	valid_0's binary_logloss: 0.58037
# [167]	valid_0's auc: 0.758271	valid_0's binary_logloss: 0.580371
# [168]	valid_0's auc: 0.75827	valid_0's binary_logloss: 0.580374
# [169]	valid_0's auc: 0.758286	valid_0's binary_logloss: 0.580363
# [170]	valid_0's auc: 0.758282	valid_0's binary_logloss: 0.580364
# [171]	valid_0's auc: 0.758281	valid_0's binary_logloss: 0.580355
# [172]	valid_0's auc: 0.758277	valid_0's binary_logloss: 0.580356
# [173]	valid_0's auc: 0.758287	valid_0's binary_logloss: 0.580346
# [174]	valid_0's auc: 0.758273	valid_0's binary_logloss: 0.580359
# [175]	valid_0's auc: 0.758273	valid_0's binary_logloss: 0.580352
# [176]	valid_0's auc: 0.758263	valid_0's binary_logloss: 0.580363
# [177]	valid_0's auc: 0.758256	valid_0's binary_logloss: 0.580373
# [178]	valid_0's auc: 0.758251	valid_0's binary_logloss: 0.580379
# [179]	valid_0's auc: 0.758249	valid_0's binary_logloss: 0.580379
# [180]	valid_0's auc: 0.758244	valid_0's binary_logloss: 0.580387
# [181]	valid_0's auc: 0.758246	valid_0's binary_logloss: 0.580384
# [182]	valid_0's auc: 0.758244	valid_0's binary_logloss: 0.580389
# [183]	valid_0's auc: 0.758232	valid_0's binary_logloss: 0.580397
# [184]	valid_0's auc: 0.758228	valid_0's binary_logloss: 0.580408
# [185]	valid_0's auc: 0.758226	valid_0's binary_logloss: 0.58041
# [186]	valid_0's auc: 0.758211	valid_0's binary_logloss: 0.58042
# [187]	valid_0's auc: 0.758207	valid_0's binary_logloss: 0.580428
# [188]	valid_0's auc: 0.758206	valid_0's binary_logloss: 0.580432
# [189]	valid_0's auc: 0.758202	valid_0's binary_logloss: 0.580441
# [190]	valid_0's auc: 0.758213	valid_0's binary_logloss: 0.58042
# [191]	valid_0's auc: 0.75821	valid_0's binary_logloss: 0.580425
# [192]	valid_0's auc: 0.758202	valid_0's binary_logloss: 0.580434
# [193]	valid_0's auc: 0.758194	valid_0's binary_logloss: 0.580439
# [194]	valid_0's auc: 0.758197	valid_0's binary_logloss: 0.580438
# [195]	valid_0's auc: 0.758201	valid_0's binary_logloss: 0.580435
# [196]	valid_0's auc: 0.758193	valid_0's binary_logloss: 0.58044
# [197]	valid_0's auc: 0.758177	valid_0's binary_logloss: 0.580454
# [198]	valid_0's auc: 0.758182	valid_0's binary_logloss: 0.58045
# [199]	valid_0's auc: 0.758179	valid_0's binary_logloss: 0.580454
# [200]	valid_0's auc: 0.75818	valid_0's binary_logloss: 0.580456
# [201]	valid_0's auc: 0.758172	valid_0's binary_logloss: 0.58046
# [202]	valid_0's auc: 0.758167	valid_0's binary_logloss: 0.580465
# [203]	valid_0's auc: 0.758153	valid_0's binary_logloss: 0.580479
# [204]	valid_0's auc: 0.758154	valid_0's binary_logloss: 0.580478
# [205]	valid_0's auc: 0.758141	valid_0's binary_logloss: 0.580486
# [206]	valid_0's auc: 0.758113	valid_0's binary_logloss: 0.580509
# [207]	valid_0's auc: 0.758135	valid_0's binary_logloss: 0.580485
# [208]	valid_0's auc: 0.758137	valid_0's binary_logloss: 0.580487
# [209]	valid_0's auc: 0.758143	valid_0's binary_logloss: 0.580479
# [210]	valid_0's auc: 0.758148	valid_0's binary_logloss: 0.580476
# [211]	valid_0's auc: 0.758144	valid_0's binary_logloss: 0.580478
# [212]	valid_0's auc: 0.758144	valid_0's binary_logloss: 0.580479
# [213]	valid_0's auc: 0.758151	valid_0's binary_logloss: 0.580474
# [214]	valid_0's auc: 0.758153	valid_0's binary_logloss: 0.580475
# [215]	valid_0's auc: 0.758158	valid_0's binary_logloss: 0.58047
# [216]	valid_0's auc: 0.758138	valid_0's binary_logloss: 0.580491
# [217]	valid_0's auc: 0.758131	valid_0's binary_logloss: 0.580501
# [218]	valid_0's auc: 0.758155	valid_0's binary_logloss: 0.58048
# [219]	valid_0's auc: 0.758144	valid_0's binary_logloss: 0.580495
# [220]	valid_0's auc: 0.758145	valid_0's binary_logloss: 0.580494
# [221]	valid_0's auc: 0.758131	valid_0's binary_logloss: 0.580506
# [222]	valid_0's auc: 0.758168	valid_0's binary_logloss: 0.580474
# [223]	valid_0's auc: 0.758179	valid_0's binary_logloss: 0.580468
# [224]	valid_0's auc: 0.758168	valid_0's binary_logloss: 0.580473
# [225]	valid_0's auc: 0.758164	valid_0's binary_logloss: 0.580473
# [226]	valid_0's auc: 0.758159	valid_0's binary_logloss: 0.580473
# [227]	valid_0's auc: 0.758169	valid_0's binary_logloss: 0.580464
# [228]	valid_0's auc: 0.758164	valid_0's binary_logloss: 0.580471
# [229]	valid_0's auc: 0.75813	valid_0's binary_logloss: 0.580499
# [230]	valid_0's auc: 0.758135	valid_0's binary_logloss: 0.580498
# [231]	valid_0's auc: 0.758115	valid_0's binary_logloss: 0.580513
# [232]	valid_0's auc: 0.758121	valid_0's binary_logloss: 0.580511
# [233]	valid_0's auc: 0.758143	valid_0's binary_logloss: 0.580493
# [234]	valid_0's auc: 0.758153	valid_0's binary_logloss: 0.580487
# [235]	valid_0's auc: 0.758153	valid_0's binary_logloss: 0.580486
# [236]	valid_0's auc: 0.758154	valid_0's binary_logloss: 0.580485
# [237]	valid_0's auc: 0.758143	valid_0's binary_logloss: 0.580492
# [238]	valid_0's auc: 0.758145	valid_0's binary_logloss: 0.580491
# [239]	valid_0's auc: 0.758144	valid_0's binary_logloss: 0.580494
# [240]	valid_0's auc: 0.758137	valid_0's binary_logloss: 0.580499
# [241]	valid_0's auc: 0.758125	valid_0's binary_logloss: 0.580511
# [242]	valid_0's auc: 0.758129	valid_0's binary_logloss: 0.580508
# [243]	valid_0's auc: 0.758117	valid_0's binary_logloss: 0.580523
# [244]	valid_0's auc: 0.758107	valid_0's binary_logloss: 0.58053
# [245]	valid_0's auc: 0.758106	valid_0's binary_logloss: 0.580529
# [246]	valid_0's auc: 0.758115	valid_0's binary_logloss: 0.580522
# [247]	valid_0's auc: 0.758123	valid_0's binary_logloss: 0.580509
# [248]	valid_0's auc: 0.758122	valid_0's binary_logloss: 0.580514
# [249]	valid_0's auc: 0.758126	valid_0's binary_logloss: 0.580511
# [250]	valid_0's auc: 0.758133	valid_0's binary_logloss: 0.580505
# [251]	valid_0's auc: 0.758142	valid_0's binary_logloss: 0.580495
# [252]	valid_0's auc: 0.758138	valid_0's binary_logloss: 0.580497
# [253]	valid_0's auc: 0.758126	valid_0's binary_logloss: 0.580513
# [254]	valid_0's auc: 0.758131	valid_0's binary_logloss: 0.580512
# [255]	valid_0's auc: 0.758133	valid_0's binary_logloss: 0.580509
# [256]	valid_0's auc: 0.758146	valid_0's binary_logloss: 0.580498
# [257]	valid_0's auc: 0.758157	valid_0's binary_logloss: 0.580491
# [258]	valid_0's auc: 0.758184	valid_0's binary_logloss: 0.580461
# [259]	valid_0's auc: 0.758199	valid_0's binary_logloss: 0.580442
# [260]	valid_0's auc: 0.758205	valid_0's binary_logloss: 0.580434
# [261]	valid_0's auc: 0.758197	valid_0's binary_logloss: 0.580441
# [262]	valid_0's auc: 0.758189	valid_0's binary_logloss: 0.580448
# [263]	valid_0's auc: 0.75818	valid_0's binary_logloss: 0.580461
# [264]	valid_0's auc: 0.758195	valid_0's binary_logloss: 0.580448
# [265]	valid_0's auc: 0.758196	valid_0's binary_logloss: 0.580447
# [266]	valid_0's auc: 0.7582	valid_0's binary_logloss: 0.580447
# [267]	valid_0's auc: 0.758189	valid_0's binary_logloss: 0.580454
# [268]	valid_0's auc: 0.758193	valid_0's binary_logloss: 0.580451
# [269]	valid_0's auc: 0.758191	valid_0's binary_logloss: 0.580453
# [270]	valid_0's auc: 0.75818	valid_0's binary_logloss: 0.580464
# [271]	valid_0's auc: 0.758174	valid_0's binary_logloss: 0.580471
# [272]	valid_0's auc: 0.758176	valid_0's binary_logloss: 0.580472
# [273]	valid_0's auc: 0.758166	valid_0's binary_logloss: 0.580484
# [274]	valid_0's auc: 0.758167	valid_0's binary_logloss: 0.580486
# [275]	valid_0's auc: 0.758153	valid_0's binary_logloss: 0.580496
# [276]	valid_0's auc: 0.758129	valid_0's binary_logloss: 0.580518
# [277]	valid_0's auc: 0.758138	valid_0's binary_logloss: 0.580513
# [278]	valid_0's auc: 0.75814	valid_0's binary_logloss: 0.580513
# [279]	valid_0's auc: 0.758144	valid_0's binary_logloss: 0.580507
# [280]	valid_0's auc: 0.758139	valid_0's binary_logloss: 0.58051
# [281]	valid_0's auc: 0.75814	valid_0's binary_logloss: 0.580508
# [282]	valid_0's auc: 0.758149	valid_0's binary_logloss: 0.580497
# [283]	valid_0's auc: 0.758164	valid_0's binary_logloss: 0.580486
# [284]	valid_0's auc: 0.758155	valid_0's binary_logloss: 0.580498
# [285]	valid_0's auc: 0.758157	valid_0's binary_logloss: 0.580497
# [286]	valid_0's auc: 0.75815	valid_0's binary_logloss: 0.580507
# [287]	valid_0's auc: 0.758134	valid_0's binary_logloss: 0.580524
# [288]	valid_0's auc: 0.758135	valid_0's binary_logloss: 0.580521
# [289]	valid_0's auc: 0.758137	valid_0's binary_logloss: 0.580525
# [290]	valid_0's auc: 0.758138	valid_0's binary_logloss: 0.580525
# [291]	valid_0's auc: 0.758142	valid_0's binary_logloss: 0.580525
# [292]	valid_0's auc: 0.758132	valid_0's binary_logloss: 0.580533
# [293]	valid_0's auc: 0.758123	valid_0's binary_logloss: 0.580541
# [294]	valid_0's auc: 0.758129	valid_0's binary_logloss: 0.580536
# [295]	valid_0's auc: 0.758122	valid_0's binary_logloss: 0.580548
# [296]	valid_0's auc: 0.758131	valid_0's binary_logloss: 0.580533
# [297]	valid_0's auc: 0.758132	valid_0's binary_logloss: 0.580536
# [298]	valid_0's auc: 0.758109	valid_0's binary_logloss: 0.580553
# [299]	valid_0's auc: 0.758109	valid_0's binary_logloss: 0.580552
# [300]	valid_0's auc: 0.758123	valid_0's binary_logloss: 0.580538
# [301]	valid_0's auc: 0.758129	valid_0's binary_logloss: 0.580534
# [302]	valid_0's auc: 0.758143	valid_0's binary_logloss: 0.580528
# [303]	valid_0's auc: 0.758151	valid_0's binary_logloss: 0.580521
# [304]	valid_0's auc: 0.758159	valid_0's binary_logloss: 0.580518
# [305]	valid_0's auc: 0.758165	valid_0's binary_logloss: 0.580511
# [306]	valid_0's auc: 0.758161	valid_0's binary_logloss: 0.580512
# [307]	valid_0's auc: 0.75817	valid_0's binary_logloss: 0.580504
# [308]	valid_0's auc: 0.758183	valid_0's binary_logloss: 0.580491
# [309]	valid_0's auc: 0.758185	valid_0's binary_logloss: 0.580485
# [310]	valid_0's auc: 0.758191	valid_0's binary_logloss: 0.580478
# [311]	valid_0's auc: 0.758206	valid_0's binary_logloss: 0.580462
# [312]	valid_0's auc: 0.75821	valid_0's binary_logloss: 0.580459
# [313]	valid_0's auc: 0.758205	valid_0's binary_logloss: 0.580462
# [314]	valid_0's auc: 0.758207	valid_0's binary_logloss: 0.580461
# [315]	valid_0's auc: 0.758211	valid_0's binary_logloss: 0.580459
# [316]	valid_0's auc: 0.758221	valid_0's binary_logloss: 0.580449
# [317]	valid_0's auc: 0.7582	valid_0's binary_logloss: 0.580468
# [318]	valid_0's auc: 0.758198	valid_0's binary_logloss: 0.580469
# [319]	valid_0's auc: 0.758196	valid_0's binary_logloss: 0.580468
# [320]	valid_0's auc: 0.758196	valid_0's binary_logloss: 0.580466
# [321]	valid_0's auc: 0.758188	valid_0's binary_logloss: 0.580474
# [322]	valid_0's auc: 0.758193	valid_0's binary_logloss: 0.580472
# [323]	valid_0's auc: 0.758191	valid_0's binary_logloss: 0.580465
# [324]	valid_0's auc: 0.758176	valid_0's binary_logloss: 0.580482
# [325]	valid_0's auc: 0.75818	valid_0's binary_logloss: 0.580481
# [326]	valid_0's auc: 0.758177	valid_0's binary_logloss: 0.580486
# [327]	valid_0's auc: 0.758157	valid_0's binary_logloss: 0.580502
# [328]	valid_0's auc: 0.758161	valid_0's binary_logloss: 0.5805
# [329]	valid_0's auc: 0.758169	valid_0's binary_logloss: 0.580493
# [330]	valid_0's auc: 0.75816	valid_0's binary_logloss: 0.580501
# [331]	valid_0's auc: 0.758165	valid_0's binary_logloss: 0.580498
# [332]	valid_0's auc: 0.758152	valid_0's binary_logloss: 0.580506
# [333]	valid_0's auc: 0.75817	valid_0's binary_logloss: 0.580491
# [334]	valid_0's auc: 0.75817	valid_0's binary_logloss: 0.58049
# [335]	valid_0's auc: 0.758157	valid_0's binary_logloss: 0.580499
# [336]	valid_0's auc: 0.758155	valid_0's binary_logloss: 0.580505
# [337]	valid_0's auc: 0.758146	valid_0's binary_logloss: 0.580517
# [338]	valid_0's auc: 0.758141	valid_0's binary_logloss: 0.580518
# [339]	valid_0's auc: 0.758163	valid_0's binary_logloss: 0.580498
# [340]	valid_0's auc: 0.75817	valid_0's binary_logloss: 0.580495
# [341]	valid_0's auc: 0.758162	valid_0's binary_logloss: 0.580503
# [342]	valid_0's auc: 0.758148	valid_0's binary_logloss: 0.580515
# [343]	valid_0's auc: 0.758135	valid_0's binary_logloss: 0.580526
# [344]	valid_0's auc: 0.758125	valid_0's binary_logloss: 0.580535
# [345]	valid_0's auc: 0.758135	valid_0's binary_logloss: 0.580523
# [346]	valid_0's auc: 0.758138	valid_0's binary_logloss: 0.580519
# [347]	valid_0's auc: 0.758123	valid_0's binary_logloss: 0.580526
# [348]	valid_0's auc: 0.758134	valid_0's binary_logloss: 0.580514
# [349]	valid_0's auc: 0.758129	valid_0's binary_logloss: 0.580515
# [350]	valid_0's auc: 0.758126	valid_0's binary_logloss: 0.580516
# [351]	valid_0's auc: 0.758123	valid_0's binary_logloss: 0.58052
# [352]	valid_0's auc: 0.75813	valid_0's binary_logloss: 0.580516
# [353]	valid_0's auc: 0.758115	valid_0's binary_logloss: 0.580528
# [354]	valid_0's auc: 0.758117	valid_0's binary_logloss: 0.580538
# [355]	valid_0's auc: 0.758099	valid_0's binary_logloss: 0.580549
# [356]	valid_0's auc: 0.758103	valid_0's binary_logloss: 0.580547
# [357]	valid_0's auc: 0.758103	valid_0's binary_logloss: 0.580547
# [358]	valid_0's auc: 0.758122	valid_0's binary_logloss: 0.58053
# [359]	valid_0's auc: 0.758126	valid_0's binary_logloss: 0.580528
# [360]	valid_0's auc: 0.758107	valid_0's binary_logloss: 0.580548
# [361]	valid_0's auc: 0.758126	valid_0's binary_logloss: 0.580531
# [362]	valid_0's auc: 0.758149	valid_0's binary_logloss: 0.580515
# [363]	valid_0's auc: 0.758153	valid_0's binary_logloss: 0.58051
# [364]	valid_0's auc: 0.758145	valid_0's binary_logloss: 0.580515
# [365]	valid_0's auc: 0.758148	valid_0's binary_logloss: 0.580507
# [366]	valid_0's auc: 0.758148	valid_0's binary_logloss: 0.580505
# [367]	valid_0's auc: 0.758141	valid_0's binary_logloss: 0.580513
# [368]	valid_0's auc: 0.758138	valid_0's binary_logloss: 0.580519
# [369]	valid_0's auc: 0.758141	valid_0's binary_logloss: 0.580521
# [370]	valid_0's auc: 0.758147	valid_0's binary_logloss: 0.580514
# [371]	valid_0's auc: 0.758141	valid_0's binary_logloss: 0.580523
# [372]	valid_0's auc: 0.758133	valid_0's binary_logloss: 0.580534
# [373]	valid_0's auc: 0.758134	valid_0's binary_logloss: 0.580533
# [374]	valid_0's auc: 0.758126	valid_0's binary_logloss: 0.580533
# [375]	valid_0's auc: 0.758127	valid_0's binary_logloss: 0.580537
# [376]	valid_0's auc: 0.758104	valid_0's binary_logloss: 0.580555
# [377]	valid_0's auc: 0.758097	valid_0's binary_logloss: 0.580559
# [378]	valid_0's auc: 0.758094	valid_0's binary_logloss: 0.580561
# [379]	valid_0's auc: 0.758076	valid_0's binary_logloss: 0.580579
# [380]	valid_0's auc: 0.758066	valid_0's binary_logloss: 0.58059
# [381]	valid_0's auc: 0.75808	valid_0's binary_logloss: 0.580578
# [382]	valid_0's auc: 0.758085	valid_0's binary_logloss: 0.580575
# [383]	valid_0's auc: 0.758065	valid_0's binary_logloss: 0.580593
# [384]	valid_0's auc: 0.758079	valid_0's binary_logloss: 0.580586
# [385]	valid_0's auc: 0.758062	valid_0's binary_logloss: 0.580597
# [386]	valid_0's auc: 0.758062	valid_0's binary_logloss: 0.580597
# [387]	valid_0's auc: 0.75805	valid_0's binary_logloss: 0.580607
# [388]	valid_0's auc: 0.758043	valid_0's binary_logloss: 0.580614
# [389]	valid_0's auc: 0.758027	valid_0's binary_logloss: 0.580627
# [390]	valid_0's auc: 0.758018	valid_0's binary_logloss: 0.58063
# [391]	valid_0's auc: 0.758025	valid_0's binary_logloss: 0.58062
# [392]	valid_0's auc: 0.758023	valid_0's binary_logloss: 0.580621
# [393]	valid_0's auc: 0.758011	valid_0's binary_logloss: 0.580628
# [394]	valid_0's auc: 0.758011	valid_0's binary_logloss: 0.580633
# [395]	valid_0's auc: 0.758032	valid_0's binary_logloss: 0.580616
# [396]	valid_0's auc: 0.758017	valid_0's binary_logloss: 0.580636
# [397]	valid_0's auc: 0.758013	valid_0's binary_logloss: 0.58064
# [398]	valid_0's auc: 0.758017	valid_0's binary_logloss: 0.580632
# [399]	valid_0's auc: 0.758008	valid_0's binary_logloss: 0.580643
# [400]	valid_0's auc: 0.758005	valid_0's binary_logloss: 0.580649
# [401]	valid_0's auc: 0.757995	valid_0's binary_logloss: 0.580655
# [402]	valid_0's auc: 0.757993	valid_0's binary_logloss: 0.580661
# [403]	valid_0's auc: 0.757998	valid_0's binary_logloss: 0.58066
# [404]	valid_0's auc: 0.757991	valid_0's binary_logloss: 0.580663
# [405]	valid_0's auc: 0.757988	valid_0's binary_logloss: 0.580666
# [406]	valid_0's auc: 0.757983	valid_0's binary_logloss: 0.580668
# [407]	valid_0's auc: 0.757979	valid_0's binary_logloss: 0.580675
# [408]	valid_0's auc: 0.757984	valid_0's binary_logloss: 0.580669
# [409]	valid_0's auc: 0.757981	valid_0's binary_logloss: 0.580677
# [410]	valid_0's auc: 0.757975	valid_0's binary_logloss: 0.580681
# [411]	valid_0's auc: 0.757952	valid_0's binary_logloss: 0.5807
# [412]	valid_0's auc: 0.757944	valid_0's binary_logloss: 0.58071
# [413]	valid_0's auc: 0.757934	valid_0's binary_logloss: 0.580717
# [414]	valid_0's auc: 0.757933	valid_0's binary_logloss: 0.580718
# [415]	valid_0's auc: 0.757942	valid_0's binary_logloss: 0.580709
# [416]	valid_0's auc: 0.757947	valid_0's binary_logloss: 0.580707
# [417]	valid_0's auc: 0.757963	valid_0's binary_logloss: 0.580694
# [418]	valid_0's auc: 0.757957	valid_0's binary_logloss: 0.580703
# [419]	valid_0's auc: 0.757941	valid_0's binary_logloss: 0.580714
# [420]	valid_0's auc: 0.757932	valid_0's binary_logloss: 0.580723
# [421]	valid_0's auc: 0.757921	valid_0's binary_logloss: 0.580735
# [422]	valid_0's auc: 0.757902	valid_0's binary_logloss: 0.580751
# [423]	valid_0's auc: 0.757898	valid_0's binary_logloss: 0.58075
# [424]	valid_0's auc: 0.757896	valid_0's binary_logloss: 0.580752
# [425]	valid_0's auc: 0.757891	valid_0's binary_logloss: 0.580754
# [426]	valid_0's auc: 0.757896	valid_0's binary_logloss: 0.580751
# [427]	valid_0's auc: 0.757891	valid_0's binary_logloss: 0.580749
# [428]	valid_0's auc: 0.757881	valid_0's binary_logloss: 0.580756
# [429]	valid_0's auc: 0.757883	valid_0's binary_logloss: 0.580752
# [430]	valid_0's auc: 0.757859	valid_0's binary_logloss: 0.580771
# [431]	valid_0's auc: 0.75786	valid_0's binary_logloss: 0.580769
# [432]	valid_0's auc: 0.757867	valid_0's binary_logloss: 0.580767
# [433]	valid_0's auc: 0.75786	valid_0's binary_logloss: 0.580774
# [434]	valid_0's auc: 0.757847	valid_0's binary_logloss: 0.580789
# [435]	valid_0's auc: 0.757842	valid_0's binary_logloss: 0.58079
# [436]	valid_0's auc: 0.75783	valid_0's binary_logloss: 0.580803
# [437]	valid_0's auc: 0.757831	valid_0's binary_logloss: 0.580802
# [438]	valid_0's auc: 0.757813	valid_0's binary_logloss: 0.58082
# [439]	valid_0's auc: 0.757807	valid_0's binary_logloss: 0.580825
# [440]	valid_0's auc: 0.757795	valid_0's binary_logloss: 0.580837
# [441]	valid_0's auc: 0.75779	valid_0's binary_logloss: 0.58084
# [442]	valid_0's auc: 0.757777	valid_0's binary_logloss: 0.580851
# [443]	valid_0's auc: 0.75779	valid_0's binary_logloss: 0.580836
# [444]	valid_0's auc: 0.757798	valid_0's binary_logloss: 0.580834
# [445]	valid_0's auc: 0.757807	valid_0's binary_logloss: 0.580826
# [446]	valid_0's auc: 0.757797	valid_0's binary_logloss: 0.580835
# [447]	valid_0's auc: 0.757795	valid_0's binary_logloss: 0.580838
# [448]	valid_0's auc: 0.757791	valid_0's binary_logloss: 0.580843
# [449]	valid_0's auc: 0.757792	valid_0's binary_logloss: 0.580847
# [450]	valid_0's auc: 0.757791	valid_0's binary_logloss: 0.580846
# [451]	valid_0's auc: 0.757794	valid_0's binary_logloss: 0.580844
# [452]	valid_0's auc: 0.757806	valid_0's binary_logloss: 0.580833
# [453]	valid_0's auc: 0.757809	valid_0's binary_logloss: 0.580836
# [454]	valid_0's auc: 0.757811	valid_0's binary_logloss: 0.580842
# [455]	valid_0's auc: 0.757814	valid_0's binary_logloss: 0.58084
# [456]	valid_0's auc: 0.757809	valid_0's binary_logloss: 0.580846
# [457]	valid_0's auc: 0.757808	valid_0's binary_logloss: 0.580851
# [458]	valid_0's auc: 0.75779	valid_0's binary_logloss: 0.580865
# [459]	valid_0's auc: 0.75778	valid_0's binary_logloss: 0.580874
# [460]	valid_0's auc: 0.757782	valid_0's binary_logloss: 0.580869
# [461]	valid_0's auc: 0.757774	valid_0's binary_logloss: 0.580874
# [462]	valid_0's auc: 0.757774	valid_0's binary_logloss: 0.580875
# [463]	valid_0's auc: 0.757775	valid_0's binary_logloss: 0.580876
# [464]	valid_0's auc: 0.757765	valid_0's binary_logloss: 0.580883
# [465]	valid_0's auc: 0.757749	valid_0's binary_logloss: 0.580896
# [466]	valid_0's auc: 0.757732	valid_0's binary_logloss: 0.580912
# [467]	valid_0's auc: 0.757735	valid_0's binary_logloss: 0.58091
# [468]	valid_0's auc: 0.75773	valid_0's binary_logloss: 0.58091
# [469]	valid_0's auc: 0.757744	valid_0's binary_logloss: 0.580895
# [470]	valid_0's auc: 0.757743	valid_0's binary_logloss: 0.580897
# [471]	valid_0's auc: 0.757743	valid_0's binary_logloss: 0.580896
# [472]	valid_0's auc: 0.757748	valid_0's binary_logloss: 0.580895
# [473]	valid_0's auc: 0.757743	valid_0's binary_logloss: 0.580898
# [474]	valid_0's auc: 0.757727	valid_0's binary_logloss: 0.580914
# [475]	valid_0's auc: 0.757702	valid_0's binary_logloss: 0.580936
# [476]	valid_0's auc: 0.757692	valid_0's binary_logloss: 0.580944
# [477]	valid_0's auc: 0.757696	valid_0's binary_logloss: 0.580943
# [478]	valid_0's auc: 0.757694	valid_0's binary_logloss: 0.580944
# [479]	valid_0's auc: 0.757693	valid_0's binary_logloss: 0.580947
# [480]	valid_0's auc: 0.757685	valid_0's binary_logloss: 0.580955
# [481]	valid_0's auc: 0.757692	valid_0's binary_logloss: 0.580948
# [482]	valid_0's auc: 0.757683	valid_0's binary_logloss: 0.580955
# [483]	valid_0's auc: 0.757677	valid_0's binary_logloss: 0.58096
# [484]	valid_0's auc: 0.75767	valid_0's binary_logloss: 0.580965
# [485]	valid_0's auc: 0.757662	valid_0's binary_logloss: 0.580966
# [486]	valid_0's auc: 0.757664	valid_0's binary_logloss: 0.580964
# [487]	valid_0's auc: 0.757645	valid_0's binary_logloss: 0.580979
# [488]	valid_0's auc: 0.75765	valid_0's binary_logloss: 0.580966
# [489]	valid_0's auc: 0.757651	valid_0's binary_logloss: 0.580966
# [490]	valid_0's auc: 0.75764	valid_0's binary_logloss: 0.580975
# [491]	valid_0's auc: 0.757625	valid_0's binary_logloss: 0.580989
# [492]	valid_0's auc: 0.757621	valid_0's binary_logloss: 0.580989
# [493]	valid_0's auc: 0.757623	valid_0's binary_logloss: 0.580985
# [494]	valid_0's auc: 0.757617	valid_0's binary_logloss: 0.580995
# [495]	valid_0's auc: 0.757639	valid_0's binary_logloss: 0.580977
# [496]	valid_0's auc: 0.75764	valid_0's binary_logloss: 0.580971
# [497]	valid_0's auc: 0.757626	valid_0's binary_logloss: 0.580983
# [498]	valid_0's auc: 0.757629	valid_0's binary_logloss: 0.580978
# [499]	valid_0's auc: 0.757629	valid_0's binary_logloss: 0.58098
# [500]	valid_0's auc: 0.757628	valid_0's binary_logloss: 0.580975
# [501]	valid_0's auc: 0.757627	valid_0's binary_logloss: 0.580975
# [502]	valid_0's auc: 0.757619	valid_0's binary_logloss: 0.580984
# [503]	valid_0's auc: 0.757601	valid_0's binary_logloss: 0.580997
# [504]	valid_0's auc: 0.757578	valid_0's binary_logloss: 0.581017
# [505]	valid_0's auc: 0.757579	valid_0's binary_logloss: 0.58102
# [506]	valid_0's auc: 0.757578	valid_0's binary_logloss: 0.581025
# [507]	valid_0's auc: 0.757576	valid_0's binary_logloss: 0.581029
# [508]	valid_0's auc: 0.757571	valid_0's binary_logloss: 0.581033
# [509]	valid_0's auc: 0.757566	valid_0's binary_logloss: 0.58104
# [510]	valid_0's auc: 0.757555	valid_0's binary_logloss: 0.581047
# [511]	valid_0's auc: 0.757552	valid_0's binary_logloss: 0.581055
# [512]	valid_0's auc: 0.757555	valid_0's binary_logloss: 0.581049
# [513]	valid_0's auc: 0.757551	valid_0's binary_logloss: 0.581053
# [514]	valid_0's auc: 0.757552	valid_0's binary_logloss: 0.581054
# [515]	valid_0's auc: 0.757556	valid_0's binary_logloss: 0.58105
# [516]	valid_0's auc: 0.757551	valid_0's binary_logloss: 0.581052
# [517]	valid_0's auc: 0.757534	valid_0's binary_logloss: 0.581069
# [518]	valid_0's auc: 0.757542	valid_0's binary_logloss: 0.581063
# [519]	valid_0's auc: 0.757537	valid_0's binary_logloss: 0.58107
# [520]	valid_0's auc: 0.757536	valid_0's binary_logloss: 0.581076
# [521]	valid_0's auc: 0.757537	valid_0's binary_logloss: 0.581076
# [522]	valid_0's auc: 0.757533	valid_0's binary_logloss: 0.581078
# [523]	valid_0's auc: 0.757531	valid_0's binary_logloss: 0.58108
# [524]	valid_0's auc: 0.757537	valid_0's binary_logloss: 0.581075
# [525]	valid_0's auc: 0.757526	valid_0's binary_logloss: 0.581084
# [526]	valid_0's auc: 0.757507	valid_0's binary_logloss: 0.581099
# [527]	valid_0's auc: 0.75751	valid_0's binary_logloss: 0.581097
# [528]	valid_0's auc: 0.7575	valid_0's binary_logloss: 0.581109
# [529]	valid_0's auc: 0.757495	valid_0's binary_logloss: 0.581112
# [530]	valid_0's auc: 0.757486	valid_0's binary_logloss: 0.581123
# [531]	valid_0's auc: 0.757489	valid_0's binary_logloss: 0.581123
# [532]	valid_0's auc: 0.757501	valid_0's binary_logloss: 0.581109
# [533]	valid_0's auc: 0.757491	valid_0's binary_logloss: 0.581118
# [534]	valid_0's auc: 0.757497	valid_0's binary_logloss: 0.581108
# [535]	valid_0's auc: 0.757489	valid_0's binary_logloss: 0.581115
# [536]	valid_0's auc: 0.757475	valid_0's binary_logloss: 0.581129
# [537]	valid_0's auc: 0.75747	valid_0's binary_logloss: 0.581136
# [538]	valid_0's auc: 0.757462	valid_0's binary_logloss: 0.58114
# [539]	valid_0's auc: 0.757447	valid_0's binary_logloss: 0.581154
# [540]	valid_0's auc: 0.757436	valid_0's binary_logloss: 0.581163
# [541]	valid_0's auc: 0.75743	valid_0's binary_logloss: 0.581168
# [542]	valid_0's auc: 0.75742	valid_0's binary_logloss: 0.581182
# [543]	valid_0's auc: 0.757412	valid_0's binary_logloss: 0.581189
# [544]	valid_0's auc: 0.757401	valid_0's binary_logloss: 0.581196
# [545]	valid_0's auc: 0.757399	valid_0's binary_logloss: 0.581193
# [546]	valid_0's auc: 0.757393	valid_0's binary_logloss: 0.581202
# [547]	valid_0's auc: 0.757385	valid_0's binary_logloss: 0.581213
# [548]	valid_0's auc: 0.757368	valid_0's binary_logloss: 0.581229
# [549]	valid_0's auc: 0.757368	valid_0's binary_logloss: 0.581229
# [550]	valid_0's auc: 0.75734	valid_0's binary_logloss: 0.581253
# [551]	valid_0's auc: 0.75734	valid_0's binary_logloss: 0.581253
# [552]	valid_0's auc: 0.757332	valid_0's binary_logloss: 0.581258
# [553]	valid_0's auc: 0.757325	valid_0's binary_logloss: 0.581271
# [554]	valid_0's auc: 0.757331	valid_0's binary_logloss: 0.581261
# [555]	valid_0's auc: 0.757335	valid_0's binary_logloss: 0.581255
# [556]	valid_0's auc: 0.757328	valid_0's binary_logloss: 0.581264
# [557]	valid_0's auc: 0.757331	valid_0's binary_logloss: 0.581267
# [558]	valid_0's auc: 0.757344	valid_0's binary_logloss: 0.581256
# [559]	valid_0's auc: 0.757326	valid_0's binary_logloss: 0.58127
# [560]	valid_0's auc: 0.757319	valid_0's binary_logloss: 0.58128
# [561]	valid_0's auc: 0.757315	valid_0's binary_logloss: 0.581284
# [562]	valid_0's auc: 0.757314	valid_0's binary_logloss: 0.581286
# [563]	valid_0's auc: 0.757309	valid_0's binary_logloss: 0.581289
# [564]	valid_0's auc: 0.757307	valid_0's binary_logloss: 0.581291
# [565]	valid_0's auc: 0.757301	valid_0's binary_logloss: 0.581298
# [566]	valid_0's auc: 0.757297	valid_0's binary_logloss: 0.581301
# [567]	valid_0's auc: 0.757305	valid_0's binary_logloss: 0.581295
# [568]	valid_0's auc: 0.757312	valid_0's binary_logloss: 0.581288
# [569]	valid_0's auc: 0.757307	valid_0's binary_logloss: 0.581293
# [570]	valid_0's auc: 0.757313	valid_0's binary_logloss: 0.581292
# [571]	valid_0's auc: 0.75731	valid_0's binary_logloss: 0.581294
# [572]	valid_0's auc: 0.7573	valid_0's binary_logloss: 0.581307
# [573]	valid_0's auc: 0.757295	valid_0's binary_logloss: 0.581313
# [574]	valid_0's auc: 0.757292	valid_0's binary_logloss: 0.581313
# [575]	valid_0's auc: 0.757281	valid_0's binary_logloss: 0.581326
# [576]	valid_0's auc: 0.757281	valid_0's binary_logloss: 0.581322
# [577]	valid_0's auc: 0.757274	valid_0's binary_logloss: 0.581329
# [578]	valid_0's auc: 0.757278	valid_0's binary_logloss: 0.58133
# [579]	valid_0's auc: 0.757271	valid_0's binary_logloss: 0.581334
# [580]	valid_0's auc: 0.757264	valid_0's binary_logloss: 0.581343
# [581]	valid_0's auc: 0.757259	valid_0's binary_logloss: 0.581353
# [582]	valid_0's auc: 0.757255	valid_0's binary_logloss: 0.581358
# [583]	valid_0's auc: 0.757254	valid_0's binary_logloss: 0.581356
# [584]	valid_0's auc: 0.757238	valid_0's binary_logloss: 0.581371
# [585]	valid_0's auc: 0.757251	valid_0's binary_logloss: 0.581362
# [586]	valid_0's auc: 0.757255	valid_0's binary_logloss: 0.581361
# [587]	valid_0's auc: 0.757255	valid_0's binary_logloss: 0.581364
# [588]	valid_0's auc: 0.757269	valid_0's binary_logloss: 0.581348
# [589]	valid_0's auc: 0.757284	valid_0's binary_logloss: 0.581335
# [590]	valid_0's auc: 0.757287	valid_0's binary_logloss: 0.58133
# [591]	valid_0's auc: 0.757277	valid_0's binary_logloss: 0.581337
# [592]	valid_0's auc: 0.757298	valid_0's binary_logloss: 0.581322
# [593]	valid_0's auc: 0.7573	valid_0's binary_logloss: 0.581321
# [594]	valid_0's auc: 0.757304	valid_0's binary_logloss: 0.58132
# [595]	valid_0's auc: 0.757287	valid_0's binary_logloss: 0.581333
# [596]	valid_0's auc: 0.757289	valid_0's binary_logloss: 0.581334
# [597]	valid_0's auc: 0.757293	valid_0's binary_logloss: 0.581329
# [598]	valid_0's auc: 0.757276	valid_0's binary_logloss: 0.581343
# [599]	valid_0's auc: 0.757276	valid_0's binary_logloss: 0.581343
# [600]	valid_0's auc: 0.757274	valid_0's binary_logloss: 0.58134
# [601]	valid_0's auc: 0.757257	valid_0's binary_logloss: 0.581359
# [602]	valid_0's auc: 0.757255	valid_0's binary_logloss: 0.58136
# [603]	valid_0's auc: 0.757254	valid_0's binary_logloss: 0.58136
# [604]	valid_0's auc: 0.757259	valid_0's binary_logloss: 0.581358
# [605]	valid_0's auc: 0.757259	valid_0's binary_logloss: 0.581358
# [606]	valid_0's auc: 0.75726	valid_0's binary_logloss: 0.581359
# [607]	valid_0's auc: 0.757251	valid_0's binary_logloss: 0.58137
# [608]	valid_0's auc: 0.757253	valid_0's binary_logloss: 0.581374
# [609]	valid_0's auc: 0.757249	valid_0's binary_logloss: 0.58138
# [610]	valid_0's auc: 0.75724	valid_0's binary_logloss: 0.581387
# [611]	valid_0's auc: 0.757227	valid_0's binary_logloss: 0.581397
# [612]	valid_0's auc: 0.757225	valid_0's binary_logloss: 0.5814
# [613]	valid_0's auc: 0.757229	valid_0's binary_logloss: 0.581396
# [614]	valid_0's auc: 0.757236	valid_0's binary_logloss: 0.581387
# [615]	valid_0's auc: 0.757227	valid_0's binary_logloss: 0.581395
# [616]	valid_0's auc: 0.75723	valid_0's binary_logloss: 0.581393
# [617]	valid_0's auc: 0.75722	valid_0's binary_logloss: 0.581401
# [618]	valid_0's auc: 0.757214	valid_0's binary_logloss: 0.581408
# [619]	valid_0's auc: 0.757225	valid_0's binary_logloss: 0.581393
# [620]	valid_0's auc: 0.75722	valid_0's binary_logloss: 0.581397
# [621]	valid_0's auc: 0.757198	valid_0's binary_logloss: 0.581413
# [622]	valid_0's auc: 0.75719	valid_0's binary_logloss: 0.581421
# [623]	valid_0's auc: 0.757191	valid_0's binary_logloss: 0.581421
# [624]	valid_0's auc: 0.757184	valid_0's binary_logloss: 0.581429
# [625]	valid_0's auc: 0.757195	valid_0's binary_logloss: 0.581413
# [626]	valid_0's auc: 0.757185	valid_0's binary_logloss: 0.581425
# [627]	valid_0's auc: 0.757178	valid_0's binary_logloss: 0.581428
# [628]	valid_0's auc: 0.757181	valid_0's binary_logloss: 0.581428
# [629]	valid_0's auc: 0.757178	valid_0's binary_logloss: 0.581432
# [630]	valid_0's auc: 0.757169	valid_0's binary_logloss: 0.581438
# [631]	valid_0's auc: 0.757179	valid_0's binary_logloss: 0.581432
# [632]	valid_0's auc: 0.757188	valid_0's binary_logloss: 0.581421
# [633]	valid_0's auc: 0.757189	valid_0's binary_logloss: 0.581422
# [634]	valid_0's auc: 0.75719	valid_0's binary_logloss: 0.581418
# [635]	valid_0's auc: 0.757189	valid_0's binary_logloss: 0.58142
# [636]	valid_0's auc: 0.757188	valid_0's binary_logloss: 0.58142
# [637]	valid_0's auc: 0.757183	valid_0's binary_logloss: 0.581429
# [638]	valid_0's auc: 0.757178	valid_0's binary_logloss: 0.581436
# [639]	valid_0's auc: 0.757179	valid_0's binary_logloss: 0.581437
# [640]	valid_0's auc: 0.757168	valid_0's binary_logloss: 0.581447
# [641]	valid_0's auc: 0.757143	valid_0's binary_logloss: 0.581463
# [642]	valid_0's auc: 0.757137	valid_0's binary_logloss: 0.581471
# [643]	valid_0's auc: 0.757115	valid_0's binary_logloss: 0.581493
# [644]	valid_0's auc: 0.757112	valid_0's binary_logloss: 0.581492
# [645]	valid_0's auc: 0.757112	valid_0's binary_logloss: 0.581482
# [646]	valid_0's auc: 0.757113	valid_0's binary_logloss: 0.581483
# [647]	valid_0's auc: 0.75711	valid_0's binary_logloss: 0.581483
# [648]	valid_0's auc: 0.757103	valid_0's binary_logloss: 0.581492
# [649]	valid_0's auc: 0.757102	valid_0's binary_logloss: 0.581493
# [650]	valid_0's auc: 0.757099	valid_0's binary_logloss: 0.581494
# [651]	valid_0's auc: 0.757103	valid_0's binary_logloss: 0.581494
# [652]	valid_0's auc: 0.757097	valid_0's binary_logloss: 0.581497
# [653]	valid_0's auc: 0.757122	valid_0's binary_logloss: 0.581473
# [654]	valid_0's auc: 0.757114	valid_0's binary_logloss: 0.581483
# [655]	valid_0's auc: 0.757095	valid_0's binary_logloss: 0.581501
# [656]	valid_0's auc: 0.757084	valid_0's binary_logloss: 0.58151
# [657]	valid_0's auc: 0.757101	valid_0's binary_logloss: 0.581498
# [658]	valid_0's auc: 0.757107	valid_0's binary_logloss: 0.581495
# [659]	valid_0's auc: 0.757113	valid_0's binary_logloss: 0.581493
# [660]	valid_0's auc: 0.757114	valid_0's binary_logloss: 0.581493
# [661]	valid_0's auc: 0.75713	valid_0's binary_logloss: 0.581485
# [662]	valid_0's auc: 0.75712	valid_0's binary_logloss: 0.581497
# [663]	valid_0's auc: 0.757127	valid_0's binary_logloss: 0.581491
# [664]	valid_0's auc: 0.757115	valid_0's binary_logloss: 0.5815
# [665]	valid_0's auc: 0.757109	valid_0's binary_logloss: 0.581506
# [666]	valid_0's auc: 0.757111	valid_0's binary_logloss: 0.581501
# [667]	valid_0's auc: 0.757115	valid_0's binary_logloss: 0.581502
# [668]	valid_0's auc: 0.757114	valid_0's binary_logloss: 0.581506
# [669]	valid_0's auc: 0.757103	valid_0's binary_logloss: 0.581515
# [670]	valid_0's auc: 0.75711	valid_0's binary_logloss: 0.581511
# [671]	valid_0's auc: 0.757107	valid_0's binary_logloss: 0.581511
# [672]	valid_0's auc: 0.75711	valid_0's binary_logloss: 0.5815
# [673]	valid_0's auc: 0.757102	valid_0's binary_logloss: 0.581511
# [674]	valid_0's auc: 0.757092	valid_0's binary_logloss: 0.581522
# [675]	valid_0's auc: 0.75708	valid_0's binary_logloss: 0.581533
# [676]	valid_0's auc: 0.757078	valid_0's binary_logloss: 0.581535
# [677]	valid_0's auc: 0.757081	valid_0's binary_logloss: 0.581536
# [678]	valid_0's auc: 0.757073	valid_0's binary_logloss: 0.581544
# [679]	valid_0's auc: 0.75708	valid_0's binary_logloss: 0.581525
# [680]	valid_0's auc: 0.757063	valid_0's binary_logloss: 0.581543
# [681]	valid_0's auc: 0.757052	valid_0's binary_logloss: 0.581553
# [682]	valid_0's auc: 0.757044	valid_0's binary_logloss: 0.581557
# [683]	valid_0's auc: 0.757057	valid_0's binary_logloss: 0.58155
# [684]	valid_0's auc: 0.757035	valid_0's binary_logloss: 0.581569
# [685]	valid_0's auc: 0.757036	valid_0's binary_logloss: 0.581566
# [686]	valid_0's auc: 0.75705	valid_0's binary_logloss: 0.581548
# [687]	valid_0's auc: 0.757045	valid_0's binary_logloss: 0.581551
# [688]	valid_0's auc: 0.757044	valid_0's binary_logloss: 0.581555
# [689]	valid_0's auc: 0.757043	valid_0's binary_logloss: 0.581554
# [690]	valid_0's auc: 0.757032	valid_0's binary_logloss: 0.581565
# [691]	valid_0's auc: 0.757029	valid_0's binary_logloss: 0.581566
# [692]	valid_0's auc: 0.757031	valid_0's binary_logloss: 0.581564
# [693]	valid_0's auc: 0.757028	valid_0's binary_logloss: 0.581567
# [694]	valid_0's auc: 0.757037	valid_0's binary_logloss: 0.581556
# [695]	valid_0's auc: 0.757033	valid_0's binary_logloss: 0.581556
# [696]	valid_0's auc: 0.75702	valid_0's binary_logloss: 0.581566
# [697]	valid_0's auc: 0.757008	valid_0's binary_logloss: 0.581581
# [698]	valid_0's auc: 0.756983	valid_0's binary_logloss: 0.581602
# [699]	valid_0's auc: 0.756984	valid_0's binary_logloss: 0.581602
# [700]	valid_0's auc: 0.756986	valid_0's binary_logloss: 0.581603
# [701]	valid_0's auc: 0.756988	valid_0's binary_logloss: 0.581609
# [702]	valid_0's auc: 0.756979	valid_0's binary_logloss: 0.581618
# [703]	valid_0's auc: 0.756981	valid_0's binary_logloss: 0.581618
# [704]	valid_0's auc: 0.756986	valid_0's binary_logloss: 0.581617
# [705]	valid_0's auc: 0.756974	valid_0's binary_logloss: 0.581627
# [706]	valid_0's auc: 0.756978	valid_0's binary_logloss: 0.581627
# [707]	valid_0's auc: 0.756975	valid_0's binary_logloss: 0.581628
# [708]	valid_0's auc: 0.756985	valid_0's binary_logloss: 0.581618
# [709]	valid_0's auc: 0.756993	valid_0's binary_logloss: 0.58161
# [710]	valid_0's auc: 0.756991	valid_0's binary_logloss: 0.581607
# [711]	valid_0's auc: 0.75699	valid_0's binary_logloss: 0.581613
# [712]	valid_0's auc: 0.757005	valid_0's binary_logloss: 0.581601
# [713]	valid_0's auc: 0.756994	valid_0's binary_logloss: 0.581614
# [714]	valid_0's auc: 0.757006	valid_0's binary_logloss: 0.581606
# [715]	valid_0's auc: 0.757014	valid_0's binary_logloss: 0.581603
# [716]	valid_0's auc: 0.757001	valid_0's binary_logloss: 0.581616
# [717]	valid_0's auc: 0.756991	valid_0's binary_logloss: 0.581628
# [718]	valid_0's auc: 0.756982	valid_0's binary_logloss: 0.581635
# [719]	valid_0's auc: 0.756984	valid_0's binary_logloss: 0.581635
# [720]	valid_0's auc: 0.756981	valid_0's binary_logloss: 0.581636
# [721]	valid_0's auc: 0.756994	valid_0's binary_logloss: 0.581628
# [722]	valid_0's auc: 0.756991	valid_0's binary_logloss: 0.58163
# [723]	valid_0's auc: 0.75699	valid_0's binary_logloss: 0.581633
# [724]	valid_0's auc: 0.756992	valid_0's binary_logloss: 0.581633
# [725]	valid_0's auc: 0.756987	valid_0's binary_logloss: 0.581637
# [726]	valid_0's auc: 0.75699	valid_0's binary_logloss: 0.581634
# [727]	valid_0's auc: 0.756985	valid_0's binary_logloss: 0.581637
# [728]	valid_0's auc: 0.756998	valid_0's binary_logloss: 0.581627
# [729]	valid_0's auc: 0.757009	valid_0's binary_logloss: 0.58162
# [730]	valid_0's auc: 0.757001	valid_0's binary_logloss: 0.58163
# [731]	valid_0's auc: 0.757005	valid_0's binary_logloss: 0.581626
# [732]	valid_0's auc: 0.757011	valid_0's binary_logloss: 0.581622
# [733]	valid_0's auc: 0.756991	valid_0's binary_logloss: 0.58164
# [734]	valid_0's auc: 0.756991	valid_0's binary_logloss: 0.581642
# [735]	valid_0's auc: 0.756987	valid_0's binary_logloss: 0.581645
# ...
# [3102]	valid_0's auc: 0.750828	valid_0's binary_logloss: 0.591392
# [3103]	valid_0's auc: 0.750823	valid_0's binary_logloss: 0.591401
# [3104]	valid_0's auc: 0.750823	valid_0's binary_logloss: 0.591402
# [3105]	valid_0's auc: 0.750823	valid_0's binary_logloss: 0.591405
# [3106]	valid_0's auc: 0.750816	valid_0's binary_logloss: 0.591411
# [3107]	valid_0's auc: 0.750816	valid_0's binary_logloss: 0.591418
# [3108]	valid_0's auc: 0.750806	valid_0's binary_logloss: 0.591432
# [3109]	valid_0's auc: 0.750808	valid_0's binary_logloss: 0.591429
# [3110]	valid_0's auc: 0.750805	valid_0's binary_logloss: 0.591443
# [3111]	valid_0's auc: 0.750807	valid_0's binary_logloss: 0.591444
# [3112]	valid_0's auc: 0.750807	valid_0's binary_logloss: 0.591445
# [3113]	valid_0's auc: 0.750788	valid_0's binary_logloss: 0.59146
# [3114]	valid_0's auc: 0.750808	valid_0's binary_logloss: 0.591443
# [3115]	valid_0's auc: 0.750806	valid_0's binary_logloss: 0.591449
# [3116]	valid_0's auc: 0.750808	valid_0's binary_logloss: 0.59145
# [3117]	valid_0's auc: 0.750802	valid_0's binary_logloss: 0.591452
# [3118]	valid_0's auc: 0.750805	valid_0's binary_logloss: 0.591447
# [3119]	valid_0's auc: 0.750807	valid_0's binary_logloss: 0.591445
# [3120]	valid_0's auc: 0.750807	valid_0's binary_logloss: 0.591452
# [3121]	valid_0's auc: 0.750806	valid_0's binary_logloss: 0.591458
# [3122]	valid_0's auc: 0.750802	valid_0's binary_logloss: 0.591464
# [3123]	valid_0's auc: 0.750809	valid_0's binary_logloss: 0.591458
# [3124]	valid_0's auc: 0.750812	valid_0's binary_logloss: 0.591457
# [3125]	valid_0's auc: 0.750814	valid_0's binary_logloss: 0.591452
# [3126]	valid_0's auc: 0.750808	valid_0's binary_logloss: 0.591458
# [3127]	valid_0's auc: 0.750806	valid_0's binary_logloss: 0.59146
# [3128]	valid_0's auc: 0.750815	valid_0's binary_logloss: 0.591455
# [3129]	valid_0's auc: 0.750815	valid_0's binary_logloss: 0.591461
# [3130]	valid_0's auc: 0.750809	valid_0's binary_logloss: 0.591468
# [3131]	valid_0's auc: 0.750804	valid_0's binary_logloss: 0.591471
# [3132]	valid_0's auc: 0.750794	valid_0's binary_logloss: 0.591479
# [3133]	valid_0's auc: 0.750782	valid_0's binary_logloss: 0.591489
# [3134]	valid_0's auc: 0.750786	valid_0's binary_logloss: 0.591485
# [3135]	valid_0's auc: 0.750778	valid_0's binary_logloss: 0.591496
# [3136]	valid_0's auc: 0.750791	valid_0's binary_logloss: 0.591483
# [3137]	valid_0's auc: 0.750784	valid_0's binary_logloss: 0.591495
# [3138]	valid_0's auc: 0.750785	valid_0's binary_logloss: 0.591498
# [3139]	valid_0's auc: 0.750776	valid_0's binary_logloss: 0.591505
# [3140]	valid_0's auc: 0.750779	valid_0's binary_logloss: 0.591503
# [3141]	valid_0's auc: 0.750777	valid_0's binary_logloss: 0.591511
# [3142]	valid_0's auc: 0.750779	valid_0's binary_logloss: 0.591513
# [3143]	valid_0's auc: 0.750784	valid_0's binary_logloss: 0.591514
# [3144]	valid_0's auc: 0.750789	valid_0's binary_logloss: 0.591512
# [3145]	valid_0's auc: 0.750793	valid_0's binary_logloss: 0.59151
# [3146]	valid_0's auc: 0.750772	valid_0's binary_logloss: 0.591536
# [3147]	valid_0's auc: 0.750768	valid_0's binary_logloss: 0.591548
# [3148]	valid_0's auc: 0.750775	valid_0's binary_logloss: 0.591546
# [3149]	valid_0's auc: 0.750765	valid_0's binary_logloss: 0.591558
# [3150]	valid_0's auc: 0.750757	valid_0's binary_logloss: 0.591569
# [3151]	valid_0's auc: 0.750758	valid_0's binary_logloss: 0.591569
# [3152]	valid_0's auc: 0.750741	valid_0's binary_logloss: 0.591585
# [3153]	valid_0's auc: 0.750749	valid_0's binary_logloss: 0.591579
# [3154]	valid_0's auc: 0.750755	valid_0's binary_logloss: 0.59158
# [3155]	valid_0's auc: 0.750746	valid_0's binary_logloss: 0.591592
# [3156]	valid_0's auc: 0.750749	valid_0's binary_logloss: 0.591592
# [3157]	valid_0's auc: 0.750744	valid_0's binary_logloss: 0.591596
# [3158]	valid_0's auc: 0.750743	valid_0's binary_logloss: 0.591607
# [3159]	valid_0's auc: 0.750735	valid_0's binary_logloss: 0.591618
# [3160]	valid_0's auc: 0.750734	valid_0's binary_logloss: 0.591619
# [3161]	valid_0's auc: 0.75074	valid_0's binary_logloss: 0.591619
# [3162]	valid_0's auc: 0.750732	valid_0's binary_logloss: 0.591631
# [3163]	valid_0's auc: 0.750723	valid_0's binary_logloss: 0.591639
# [3164]	valid_0's auc: 0.750718	valid_0's binary_logloss: 0.591641
# [3165]	valid_0's auc: 0.750718	valid_0's binary_logloss: 0.591639
# [3166]	valid_0's auc: 0.75072	valid_0's binary_logloss: 0.591647
# [3167]	valid_0's auc: 0.750715	valid_0's binary_logloss: 0.59165
# [3168]	valid_0's auc: 0.750703	valid_0's binary_logloss: 0.591663
# [3169]	valid_0's auc: 0.750703	valid_0's binary_logloss: 0.591664
# [3170]	valid_0's auc: 0.750699	valid_0's binary_logloss: 0.591674
# [3171]	valid_0's auc: 0.750703	valid_0's binary_logloss: 0.591671
# [3172]	valid_0's auc: 0.750705	valid_0's binary_logloss: 0.591672
# [3173]	valid_0's auc: 0.750697	valid_0's binary_logloss: 0.59168
# [3174]	valid_0's auc: 0.750688	valid_0's binary_logloss: 0.591692
# [3175]	valid_0's auc: 0.750691	valid_0's binary_logloss: 0.591691
# [3176]	valid_0's auc: 0.750684	valid_0's binary_logloss: 0.591697
# [3177]	valid_0's auc: 0.75068	valid_0's binary_logloss: 0.591703
# [3178]	valid_0's auc: 0.750678	valid_0's binary_logloss: 0.591705
# [3179]	valid_0's auc: 0.750674	valid_0's binary_logloss: 0.591712
# [3180]	valid_0's auc: 0.750679	valid_0's binary_logloss: 0.591705
# [3181]	valid_0's auc: 0.750688	valid_0's binary_logloss: 0.591698
# [3182]	valid_0's auc: 0.750696	valid_0's binary_logloss: 0.59169
# [3183]	valid_0's auc: 0.750704	valid_0's binary_logloss: 0.591692
# [3184]	valid_0's auc: 0.750708	valid_0's binary_logloss: 0.591692
# [3185]	valid_0's auc: 0.750706	valid_0's binary_logloss: 0.591696
# [3186]	valid_0's auc: 0.75071	valid_0's binary_logloss: 0.591698
# [3187]	valid_0's auc: 0.750713	valid_0's binary_logloss: 0.591693
# [3188]	valid_0's auc: 0.750711	valid_0's binary_logloss: 0.591696
# [3189]	valid_0's auc: 0.750714	valid_0's binary_logloss: 0.591693
# [3190]	valid_0's auc: 0.750714	valid_0's binary_logloss: 0.591695
# [3191]	valid_0's auc: 0.750715	valid_0's binary_logloss: 0.591707
# [3192]	valid_0's auc: 0.75072	valid_0's binary_logloss: 0.591709
# [3193]	valid_0's auc: 0.750719	valid_0's binary_logloss: 0.591712
# [3194]	valid_0's auc: 0.750719	valid_0's binary_logloss: 0.591713
# [3195]	valid_0's auc: 0.750721	valid_0's binary_logloss: 0.591712
# [3196]	valid_0's auc: 0.750714	valid_0's binary_logloss: 0.59172
# [3197]	valid_0's auc: 0.750706	valid_0's binary_logloss: 0.591725
# [3198]	valid_0's auc: 0.7507	valid_0's binary_logloss: 0.591733
# [3199]	valid_0's auc: 0.750704	valid_0's binary_logloss: 0.59173
# [3200]	valid_0's auc: 0.750707	valid_0's binary_logloss: 0.591726
# [3201]	valid_0's auc: 0.750708	valid_0's binary_logloss: 0.591733
# [3202]	valid_0's auc: 0.7507	valid_0's binary_logloss: 0.591745
# [3203]	valid_0's auc: 0.750694	valid_0's binary_logloss: 0.591755
# [3204]	valid_0's auc: 0.750693	valid_0's binary_logloss: 0.591759
# [3205]	valid_0's auc: 0.750694	valid_0's binary_logloss: 0.591762
# [3206]	valid_0's auc: 0.750702	valid_0's binary_logloss: 0.591765
# [3207]	valid_0's auc: 0.750697	valid_0's binary_logloss: 0.59177
# [3208]	valid_0's auc: 0.750696	valid_0's binary_logloss: 0.591776
# [3209]	valid_0's auc: 0.750692	valid_0's binary_logloss: 0.591786
# [3210]	valid_0's auc: 0.750699	valid_0's binary_logloss: 0.591776
# [3211]	valid_0's auc: 0.750698	valid_0's binary_logloss: 0.591785
# [3212]	valid_0's auc: 0.750703	valid_0's binary_logloss: 0.591784
# [3213]	valid_0's auc: 0.750703	valid_0's binary_logloss: 0.591789
# [3214]	valid_0's auc: 0.750702	valid_0's binary_logloss: 0.591789
# [3215]	valid_0's auc: 0.750695	valid_0's binary_logloss: 0.591799
# [3216]	valid_0's auc: 0.750692	valid_0's binary_logloss: 0.591801
# [3217]	valid_0's auc: 0.750688	valid_0's binary_logloss: 0.591807
# [3218]	valid_0's auc: 0.750681	valid_0's binary_logloss: 0.591824
# [3219]	valid_0's auc: 0.750685	valid_0's binary_logloss: 0.591825
# [3220]	valid_0's auc: 0.750675	valid_0's binary_logloss: 0.591843
# [3221]	valid_0's auc: 0.750681	valid_0's binary_logloss: 0.59184
# [3222]	valid_0's auc: 0.750672	valid_0's binary_logloss: 0.591856
# [3223]	valid_0's auc: 0.750673	valid_0's binary_logloss: 0.591859
# [3224]	valid_0's auc: 0.750674	valid_0's binary_logloss: 0.591863
# [3225]	valid_0's auc: 0.750681	valid_0's binary_logloss: 0.59186
# [3226]	valid_0's auc: 0.750682	valid_0's binary_logloss: 0.591858
# [3227]	valid_0's auc: 0.750674	valid_0's binary_logloss: 0.591873
# [3228]	valid_0's auc: 0.750674	valid_0's binary_logloss: 0.591876
# [3229]	valid_0's auc: 0.750672	valid_0's binary_logloss: 0.591882
# [3230]	valid_0's auc: 0.750664	valid_0's binary_logloss: 0.591892
# [3231]	valid_0's auc: 0.75065	valid_0's binary_logloss: 0.591904
# [3232]	valid_0's auc: 0.750633	valid_0's binary_logloss: 0.591919
# [3233]	valid_0's auc: 0.750648	valid_0's binary_logloss: 0.591908
# [3234]	valid_0's auc: 0.750648	valid_0's binary_logloss: 0.591915
# [3235]	valid_0's auc: 0.750635	valid_0's binary_logloss: 0.59193
# [3236]	valid_0's auc: 0.750644	valid_0's binary_logloss: 0.591927
# [3237]	valid_0's auc: 0.750639	valid_0's binary_logloss: 0.59193
# [3238]	valid_0's auc: 0.750645	valid_0's binary_logloss: 0.591926
# [3239]	valid_0's auc: 0.750638	valid_0's binary_logloss: 0.591942
# [3240]	valid_0's auc: 0.750639	valid_0's binary_logloss: 0.591945
# [3241]	valid_0's auc: 0.75063	valid_0's binary_logloss: 0.591953
# [3242]	valid_0's auc: 0.750634	valid_0's binary_logloss: 0.591954
# [3243]	valid_0's auc: 0.750632	valid_0's binary_logloss: 0.591957
# [3244]	valid_0's auc: 0.750635	valid_0's binary_logloss: 0.591957
# [3245]	valid_0's auc: 0.750633	valid_0's binary_logloss: 0.591963
# [3246]	valid_0's auc: 0.750627	valid_0's binary_logloss: 0.591965
# [3247]	valid_0's auc: 0.75063	valid_0's binary_logloss: 0.591966
# [3248]	valid_0's auc: 0.750626	valid_0's binary_logloss: 0.591971
# [3249]	valid_0's auc: 0.750623	valid_0's binary_logloss: 0.591978
# [3250]	valid_0's auc: 0.750625	valid_0's binary_logloss: 0.591977
# [3251]	valid_0's auc: 0.750612	valid_0's binary_logloss: 0.591991
# [3252]	valid_0's auc: 0.750609	valid_0's binary_logloss: 0.591993
# [3253]	valid_0's auc: 0.750614	valid_0's binary_logloss: 0.591991
# [3254]	valid_0's auc: 0.75062	valid_0's binary_logloss: 0.591982
# [3255]	valid_0's auc: 0.750617	valid_0's binary_logloss: 0.591989
# [3256]	valid_0's auc: 0.750615	valid_0's binary_logloss: 0.591994
# [3257]	valid_0's auc: 0.75061	valid_0's binary_logloss: 0.592
# [3258]	valid_0's auc: 0.750606	valid_0's binary_logloss: 0.592007
# [3259]	valid_0's auc: 0.750605	valid_0's binary_logloss: 0.592009
# [3260]	valid_0's auc: 0.750613	valid_0's binary_logloss: 0.592004
# [3261]	valid_0's auc: 0.750606	valid_0's binary_logloss: 0.592017
# [3262]	valid_0's auc: 0.750592	valid_0's binary_logloss: 0.592029
# [3263]	valid_0's auc: 0.750587	valid_0's binary_logloss: 0.592035
# [3264]	valid_0's auc: 0.75059	valid_0's binary_logloss: 0.592028
# [3265]	valid_0's auc: 0.750591	valid_0's binary_logloss: 0.592026
# [3266]	valid_0's auc: 0.750586	valid_0's binary_logloss: 0.592032
# [3267]	valid_0's auc: 0.750584	valid_0's binary_logloss: 0.592035
# [3268]	valid_0's auc: 0.75058	valid_0's binary_logloss: 0.592037
# [3269]	valid_0's auc: 0.75059	valid_0's binary_logloss: 0.592029
# [3270]	valid_0's auc: 0.75058	valid_0's binary_logloss: 0.592043
# [3271]	valid_0's auc: 0.750564	valid_0's binary_logloss: 0.592058
# [3272]	valid_0's auc: 0.750545	valid_0's binary_logloss: 0.59208
# [3273]	valid_0's auc: 0.750534	valid_0's binary_logloss: 0.592094
# [3274]	valid_0's auc: 0.750526	valid_0's binary_logloss: 0.592109
# [3275]	valid_0's auc: 0.750526	valid_0's binary_logloss: 0.592111
# [3276]	valid_0's auc: 0.75053	valid_0's binary_logloss: 0.592105
# [3277]	valid_0's auc: 0.75052	valid_0's binary_logloss: 0.592115
# [3278]	valid_0's auc: 0.750514	valid_0's binary_logloss: 0.592122
# [3279]	valid_0's auc: 0.750506	valid_0's binary_logloss: 0.592133
# [3280]	valid_0's auc: 0.750502	valid_0's binary_logloss: 0.592136
# [3281]	valid_0's auc: 0.750493	valid_0's binary_logloss: 0.592145
# [3282]	valid_0's auc: 0.750487	valid_0's binary_logloss: 0.592157
# [3283]	valid_0's auc: 0.750476	valid_0's binary_logloss: 0.592169
# [3284]	valid_0's auc: 0.750466	valid_0's binary_logloss: 0.592179
# [3285]	valid_0's auc: 0.750463	valid_0's binary_logloss: 0.592183
# [3286]	valid_0's auc: 0.75046	valid_0's binary_logloss: 0.592184
# [3287]	valid_0's auc: 0.750456	valid_0's binary_logloss: 0.592192
# [3288]	valid_0's auc: 0.750445	valid_0's binary_logloss: 0.5922
# [3289]	valid_0's auc: 0.750438	valid_0's binary_logloss: 0.592208
# [3290]	valid_0's auc: 0.750431	valid_0's binary_logloss: 0.592217
# [3291]	valid_0's auc: 0.750408	valid_0's binary_logloss: 0.59224
# [3292]	valid_0's auc: 0.750404	valid_0's binary_logloss: 0.592248
# [3293]	valid_0's auc: 0.750402	valid_0's binary_logloss: 0.592256
# [3294]	valid_0's auc: 0.750404	valid_0's binary_logloss: 0.592259
# [3295]	valid_0's auc: 0.750402	valid_0's binary_logloss: 0.59227
# [3296]	valid_0's auc: 0.750393	valid_0's binary_logloss: 0.592286
# [3297]	valid_0's auc: 0.750397	valid_0's binary_logloss: 0.592283
# [3298]	valid_0's auc: 0.750402	valid_0's binary_logloss: 0.592283
# [3299]	valid_0's auc: 0.750397	valid_0's binary_logloss: 0.592287
# [3300]	valid_0's auc: 0.750403	valid_0's binary_logloss: 0.592288
# [3301]	valid_0's auc: 0.750406	valid_0's binary_logloss: 0.592284
# [3302]	valid_0's auc: 0.750396	valid_0's binary_logloss: 0.592297
# [3303]	valid_0's auc: 0.750393	valid_0's binary_logloss: 0.592303
# [3304]	valid_0's auc: 0.750388	valid_0's binary_logloss: 0.592305
# [3305]	valid_0's auc: 0.75039	valid_0's binary_logloss: 0.592301
# [3306]	valid_0's auc: 0.750392	valid_0's binary_logloss: 0.592301
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-d74549358236> in <module>
#       1 import lightgbm as lgb
#       2 clf = lgb.LGBMClassifier(max_depth = -1, n_estimators = 10000, n_jobs = 12, silent = False)
# ----> 3 clf.fit(X_train, y_train, eval_set =(X_test, y_test), eval_metric = 'auc')
#
# ~\anaconda3\lib\site-packages\lightgbm\sklearn.py in fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks, init_model)
#     836                                         verbose=verbose, feature_name=feature_name,
#     837                                         categorical_feature=categorical_feature,
# --> 838                                         callbacks=callbacks, init_model=init_model)
#     839         return self
#     840
#
# ~\anaconda3\lib\site-packages\lightgbm\sklearn.py in fit(self, X, y, sample_weight, init_score, group, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_group, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks, init_model)
#     598                               evals_result=evals_result, fobj=self._fobj, feval=feval,
#     599                               verbose_eval=verbose, feature_name=feature_name,
# --> 600                               callbacks=callbacks, init_model=init_model)
#     601
#     602         if evals_result:
#
# ~\anaconda3\lib\site-packages\lightgbm\engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     250                                     evaluation_result_list=None))
#     251
# --> 252         booster.update(fobj=fobj)
#     253
#     254         evaluation_result_list = []
#
# ~\anaconda3\lib\site-packages\lightgbm\basic.py in update(self, train_set, fobj)
#    2370             _safe_call(_LIB.LGBM_BoosterUpdateOneIter(
#    2371                 self.handle,
# -> 2372                 ctypes.byref(is_finished)))
#    2373             self.__is_predicted_cur_iter = [False for _ in range_(self.__num_dataset)]
#    2374             return is_finished.value == 1
#
# KeyboardInterrupt:

# %%
pred = clf.predict_proba(X_test)[:,1]
roc_auc_score(y_test, pred)

# %%
sorted_f = np.argsort(clf.feature_importances_)

for elt in range(len(sorted_f)):
    print(clf.feature_importances_[sorted_f[-elt-1]], clf.feature_name_[sorted_f[-elt-1]])

# %%
import tensorflow as tf
from tabnet import *

tabnet_encoder = TabNet(
        num_features = X_test.shape[1],
        feature_dim = 256,
        output_dim = 128,
        feature_columns = None,
        n_step = 6,
        n_total = 4,
        n_shared = 2,
        relaxation_factor = 1.5,
        bn_epsilon = 1e-5,
        bn_momentum = 0.7,
        bn_virtual_divider = 10,
    )


# inputs = [tf.keras.Input(shape=(1,)) for i in range(4)] + [tf.keras.Input(shape=(327,))]

# in_size = [14000,8,100,20]
# out_size = [128,8,30,20]

# agg = [tf.squeeze(tf.keras.layers.Embedding(in_size[i], out_size[i])(inputs[i]), axis = 1) for i in range(len(in_size))] + [inputs[-1]]
# agg = tf.keras.layers.Concatenate(axis = 1)(agg)

inputs = tf.keras.Input(shape = (X_test.shape[1]))

enc, masks = tabnet_encoder(inputs)

out = tf.keras.layers.Dense(1, activation = 'sigmoid')(enc)
model = tf.keras.Model(inputs, out)

# %%
model.summary()

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.02, beta_1=0.9, beta_2=0.999)

model.compile(
        loss = 'binary_crossentropy',
        optimizer = optimizer,
        metrics = ['accuracy', 'AUC'])

# %%
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ReduceLROnPlateau

early = EarlyStopping(monitor='val_loss', min_delta=0.0001, patience=9, verbose=1, 
                                                mode='auto', restore_best_weights=True)

reduce = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=4, verbose=1, 
                           mode='auto', min_delta=0.0001, cooldown=0, min_lr=0)

callbacks =[early, reduce]

epochs = 1000
batch_size = 5000

ls = X_train.shape[0]//batch_size * batch_size
lt = X_test.shape[0]//batch_size * batch_size

# model.fit([elt[:ls] for elt in X_train], y_train[:ls], 
#           validation_data = ([elt[:lt] for elt in X_test], y_test[:lt]), 
#           batch_size = batch_size, epochs = epochs, callbacks=callbacks)

model.fit(X_train.values[:ls], y_train[:ls], 
          validation_data = (X_test.values[:lt], y_test[:lt]), 
          batch_size = batch_size, epochs = epochs, callbacks=callbacks)
